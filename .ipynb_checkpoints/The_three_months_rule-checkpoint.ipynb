# %% [markdown]
# # La regola dei 3 mesi (The 3 month rule)
#
# In [The 3 Month Rule | Investing In Cryptocurrencies](https://medium.com/altcoin-magazine/the-3-month-rule-investing-in-cryptocurrencies-391095d2e112) è descritto un approccio per investire in ICO o, in generale, in nuove altcoin.
#
# 3 mesi è, secondo l'autore, il periodo di tempo necessario a distinguere uno scam da un progetto serio, ed è dunque il tempo che bisogna fare trascorrere dopo l'ingresso nel mercato, prima di acquistare una altcoin.
#
# Verifichiamo in questo notebook se questo approccio funziona veramente e se, modificando alcuni parametri della strategia, si riescono ad ottenere profitti migliori.

# %%
import datetime
import json
import os
import os.path
import time

from coinmarketcap import fetch_historical_data
from utils import daterange

# %% [markdown]
# ## Configurazione

# %%
# Data di inizio dell'analisi
start_date = datetime.date(2019, 1, 1)
# Data di fine dell'analisi
end_date = datetime.date.today()

## Definizione della strategia
strategy = {}
# Durata di attesa prima di ingresso
strategy['waiting_time'] = datetime.timedelta(days = 91)
# Importo investito (in USD) per ogni nuova coin
strategy['invested_amount_usd'] = 100
# Se true, investo solo se la coin raggiunge un nuovo massimo (in USD) dopo il tempo di attesa
strategy['invest_only_on_new_max'] = False
# Elenco delle coin su cui investo
strategy['coins'] = {}

# %% [markdown]
# ## Recupero dati da CoinMarketCap
#
# Recuperiamo innanzitutto da CoinMarketCap i dati storici giornalieri sui prezzi delle cripto.

# %%
# Genero range di date
dates = daterange(start_date, end_date)

# Intervallo in secondi fra le richieste
requests_interval_seconds = 2
requests_interval_seconds_on_error = 5

# Per ogni giorno compreso nel range scarico i dati da CMC
for date in dates:
    print('%s ' % date, end='', flush=True)
    filename = date.strftime("%Y-%m-%d")
    filepath = os.path.join('Data', 'CMC-History', filename)
    if os.path.exists(filepath):
        print('✖', end=' - ', flush=True)
        continue
    try:
        data = fetch_historical_data(date,100,1)
        with open(filepath, 'w') as outfile:
            json.dump(data, outfile)
        print ('✔', end=' - ', flush=True)
        time.sleep(requests_interval_seconds)
    except Exception as e:
        # print(e)
        print('❌', end=' - ', flush=True)
        time.sleep(requests_interval_seconds_on_error)

# %% [markdown]
# ## Analisi dei dati e raccolta informazioni
#
# Analizziamo ora i dati giornalieri, raccogliendo, per ogni coin presente, le informazioni relative a:
# - data di prima apparizione su CoinMarketCap
# - data di prima emissione
# - prezzo alla prima apparizione su CoinMarketCap
# - prezzo dopo l'intervallo indicato (default 3 mesi)
# - prezzo massimo raggiunto
# - data del prezzo massimo raggiunto
# - ultimo prezzo

# %%
# Set di coin
coins = {}

# Genero range di date
dates = daterange(start_date, end_date)

for date in dates:
    filename = date.strftime("%Y-%m-%d")
    filepath = os.path.join('Data', 'CMC-History', filename)
    if not os.path.exists(filepath):
        continue
    with open(filepath, 'r') as infile:
        data = json.load(infile)
    for coin in data:
        date_added = datetime.datetime.strptime(coin['date_added'], '%Y-%m-%dT%H:%M:%S.%fZ').date()
        if date_added < start_date:
            continue
        symbol = coin['symbol']
        usd_price = coin['quote']['USD']['price']
        btc_price = coin['quote']['BTC']['price']
        if symbol in coins:
            # La coin non è nuova all'analisi
            the_coin = coins[symbol]
            # Verifico se il massimo è superato
            if usd_price > the_coin['max_price_usd']:
                the_coin['max_price_usd'] = usd_price
                the_coin['max_price_usd_date'] = date
                the_coin['max_price_usd_days_after_launch'] = \
                    (the_coin['max_price_usd_date'] - the_coin['date_added']).days
            if btc_price > the_coin['max_price_btc']:
                the_coin['max_price_btc'] = btc_price
                the_coin['max_price_btc_date'] = date
                the_coin['max_price_btc_days_after_launch'] = \
                    (the_coin['max_price_btc_date'] - the_coin['date_added']).days
            # Analisi della strategia: 
            #  verifico condizioni di entrata (waiting time ed eventuale nuovo max)
            if date > the_coin['date_start'] + strategy['waiting_time'] \
                and (not strategy['invest_only_on_new_max'] or the_coin['max_price_usd'] == usd_price) \
                and not symbol in strategy['coins']:
                strategy_coin = {
                    'investment_start_date': date,
                    'investment_buy_usd_price': usd_price,
                    'investment_buy_btc_price': btc_price,
                    'investment_coins_amount': strategy['invested_amount_usd'] / usd_price,
                    'investment_amount_usd': strategy['invested_amount_usd'],
                    'investment_amount_btc': btc_price * strategy['invested_amount_usd'] / usd_price
                }
                strategy['coins'][symbol] = strategy_coin
            # Aggiorno ultimo prezzo
            the_coin['current_price_usd'] = usd_price
            the_coin['current_price_btc'] = btc_price
        else:
            # Nuova coin
            new_coin = {
                'id': coin['id'],
                'name': coin['name'],
                'date_added': date_added,
                'date_start': date,
                'starting_price_usd': usd_price,
                'starting_price_btc': btc_price,
                'max_price_usd': usd_price,
                'max_price_btc': btc_price,
                'max_price_usd_date': date,
                'max_price_btc_date': date,
                'current_price_usd': usd_price,
                'current_price_btc': btc_price,
                'max_price_usd_days_after_launch': 0,
                'max_price_btc_days_after_launch': 0
            }
            # Aggiungo alla collezione
            coins[symbol] = new_coin
coins
# Out:
# {'ULT': {'id': 3666,
#   'name': 'Ultiledger',
#   'date_added': datetime.date(2019, 1, 7),
#   'date_start': datetime.date(2019, 1, 10),
#   'starting_price_usd': 0.00688148258865,
#   'starting_price_btc': 1.8705146706770144e-06,
#   'max_price_usd': 0.0355043587647,
#   'max_price_btc': 3.678273164168108e-06,
#   'max_price_usd_date': datetime.date(2019, 7, 31),
#   'max_price_btc_date': datetime.date(2019, 7, 29),
#   'current_price_usd': 0.0238804363935,
#   'current_price_btc': 3.3087187459375205e-06,
#   'max_price_usd_days_after_launch': 205,
#   'max_price_btc_days_after_launch': 203},
#  'XFC': {'id': 3663,
#   'name': 'Footballcoin',
#   'date_added': datetime.date(2019, 1, 3),
#   'date_start': datetime.date(2019, 1, 10),
#   'starting_price_usd': 0.0044181627587,
#   'starting_price_btc': 1.2009386278500266e-06,
#   'max_price_usd': 0.0118119945625,
#   'max_price_btc': 1.2609542314792122e-06,
#   'max_price_usd_date': datetime.date(2019, 6, 26),
#   'max_price_btc_date': datetime.date(2019, 1, 18),
#   'current_price_usd': 0.00268414169703,
#   'current_price_btc': 3.718973055338738e-07,
#   'max_price_usd_days_after_launch': 174,
#   'max_price_btc_days_after_launch': 15},
#  'FTN': {'id': 3658,
#   'name': 'Fountain',
#   'date_added': datetime.date(2019, 1, 2),
#   'date_start': datetime.date(2019, 1, 10),
#   'starting_price_usd': 0.0326248050499,
#   'starting_price_btc': 8.868027447234642e-06,
#   'max_price_usd': 0.0564495402495,
#   'max_price_btc': 1.3254087309125232e-05,
#   'max_price_usd_date': datetime.date(2019, 4, 2),
#   'max_price_btc_date': datetime.date(2019, 3, 15),
#   'current_price_usd': 0.0136917416258,
#   'current_price_btc': 1.89703912589086e-06,
#   'max_price_usd_days_after_launch': 90,
#   'max_price_btc_days_after_launch': 72},
#  'AGVC': {'id': 3664,
#   'name': 'AgaveCoin',
#   'date_added': datetime.date(2019, 1, 4),
#   'date_start': datetime.date(2019, 1, 10),
#   'starting_price_usd': 0.0097593766424,
#   'starting_price_btc': 2.652779680992121e-06,
#   'max_price_usd': 0.0800960432148,
#   'max_price_btc': 8.898046559537427e-06,
#   'max_price_usd_date': datetime.date(2019, 8, 5),
#   'max_price_btc_date': datetime.date(2019, 10, 15),
#   'current_price_usd': 0.0518068206216,
#   'current_price_btc': 7.178017844128156e-06,
#   'max_price_usd_days_after_launch': 213,
#   'max_price_btc_days_after_launch': 284},
#  'BECN': {'id': 3656,
#   'name': 'Beacon',
#   'date_added': datetime.date(2019, 1, 1),
#   'date_start': datetime.date(2019, 1, 10),
#   'starting_price_usd': 0.135177296481,
#   'starting_price_btc': 3.6743697735602474e-05,
#   'max_price_usd': 0.141807156195,
#   'max_price_btc': 3.82636691987335e-05,
#   'max_price_usd_date': datetime.date(2019, 1, 14),
#   'max_price_btc_date': datetime.date(2019, 1, 14),
#   'current_price_usd': 0.0386032498319,
#   'current_price_btc': 1.0507612956682127e-05,
#   'max_price_usd_days_after_launch': 13,
#   'max_price_btc_days_after_launch': 13},
#  'B2G': {'id': 3684,
#   'name': 'Bitcoiin',
#   'date_added': datetime.date(2019, 1, 10),
#   'date_start': datetime.date(2019, 1, 14),
#   'starting_price_usd': 0.0239043720672,
#   'starting_price_btc': 6.450090458940015e-06,
#   'max_price_usd': 0.705681561437,
#   'max_price_btc': 0.00020358014827461283,
#   'max_price_usd_date': datetime.date(2019, 2, 5),
#   'max_price_btc_date': datetime.date(2019, 2, 5),
#   'current_price_usd': 0.00544809208944,
#   'current_price_btc': 5.265988733212506e-07,
#   'max_price_usd_days_after_launch': 26,
#   'max_price_btc_days_after_launch': 26},
#  'DASHG': {'id': 3613,
#   'name': 'Dash Green',
#   'date_added': datetime.date(2019, 1, 14),
#   'date_start': datetime.date(2019, 1, 17),
#   'starting_price_usd': 0.428995996396,
#   'starting_price_btc': 0.00011662050711987308,
#   'max_price_usd': 0.428995996396,
#   'max_price_btc': 0.00011662050711987308,
#   'max_price_usd_date': datetime.date(2019, 1, 17),
#   'max_price_btc_date': datetime.date(2019, 1, 17),
#   'current_price_usd': 0.163226353862,
#   'current_price_btc': 1.425452259995105e-05,
#   'max_price_usd_days_after_launch': 0,
#   'max_price_btc_days_after_launch': 0},
#  'IMPL': {'id': 3665,
#   'name': 'Impleum',
#   'date_added': datetime.date(2019, 1, 4),
#   'date_start': datetime.date(2019, 1, 17),
#   'starting_price_usd': 0.0494995944146,
#   'starting_price_btc': 1.3456227683602955e-05,
#   'max_price_usd': 0.0542624779876,
#   'max_price_btc': 1.4553166973678039e-05,
#   'max_price_usd_date': datetime.date(2019, 1, 19),
#   'max_price_btc_date': datetime.date(2019, 1, 19),
#   'current_price_usd': 0.0382650092372,
#   'current_price_btc': 1.0867466240756626e-05,
#   'max_price_usd_days_after_launch': 15,
#   'max_price_btc_days_after_launch': 15},
#  'MCW': {'id': 3689,
#   'name': 'Mocrow',
#   'date_added': datetime.date(2019, 1, 10),
#   'date_start': datetime.date(2019, 1, 20),
#   'starting_price_usd': 0.325839197404,
#   'starting_price_btc': 9.048541171105991e-05,
#   'max_price_usd': 0.604777067886,
#   'max_price_btc': 0.00015444871478966003,
#   'max_price_usd_date': datetime.date(2019, 2, 18),
#   'max_price_btc_date': datetime.date(2019, 2, 18),
#   'current_price_usd': 0.241823029274,
#   'current_price_btc': 2.9686626614063368e-05,
#   'max_price_usd_days_after_launch': 39,
#   'max_price_btc_days_after_launch': 39},
#  'DOGEC': {'id': 3672,
#   'name': 'DogeCash',
#   'date_added': datetime.date(2019, 1, 7),
#   'date_start': datetime.date(2019, 1, 20),
#   'starting_price_usd': 0.0498366069561,
#   'starting_price_btc': 1.3839605347154659e-05,
#   'max_price_usd': 0.0932523769636,
#   'max_price_btc': 2.3383723998368398e-05,
#   'max_price_usd_date': datetime.date(2019, 3, 29),
#   'max_price_btc_date': datetime.date(2019, 3, 8),
#   'current_price_usd': 0.0932523769636,
#   'current_price_btc': 2.2753502892435848e-05,
#   'max_price_usd_days_after_launch': 81,
#   'max_price_btc_days_after_launch': 60},
#  'CVNT': {'id': 3686,
#   'name': 'Content Value Network',
#   'date_added': datetime.date(2019, 1, 9),
#   'date_start': datetime.date(2019, 1, 28),
#   'starting_price_usd': 0.0128679128347,
#   'starting_price_btc': 3.707850804417888e-06,
#   'max_price_usd': 0.0353538702927,
#   'max_price_btc': 6.996342093127951e-06,
#   'max_price_usd_date': datetime.date(2019, 8, 12),
#   'max_price_btc_date': datetime.date(2019, 3, 24),
#   'current_price_usd': 0.0061379228371,
#   'current_price_btc': 8.504308722665797e-07,
#   'max_price_usd_days_after_launch': 215,
#   'max_price_btc_days_after_launch': 74},
#  'EXO': {'id': 3708,
#   'name': 'Exosis',
#   'date_added': datetime.date(2019, 1, 28),
#   'date_start': datetime.date(2019, 2, 2),
#   'starting_price_usd': 0.823964168658,
#   'starting_price_btc': 0.00023401020841199054,
#   'max_price_usd': 0.823964168658,
#   'max_price_btc': 0.00023401020841199054,
#   'max_price_usd_date': datetime.date(2019, 2, 2),
#   'max_price_btc_date': datetime.date(2019, 2, 2),
#   'current_price_usd': 0.823964168658,
#   'current_price_btc': 0.00023401020841199054,
#   'max_price_usd_days_after_launch': 0,
#   'max_price_btc_days_after_launch': 0},
#  'WIB': {'id': 3713,
#   'name': 'Wibson',
#   'date_added': datetime.date(2019, 1, 31),
#   'date_start': datetime.date(2019, 2, 4),
#   'starting_price_usd': 0.0011845342735,
#   'starting_price_btc': 3.4243465985749337e-07,
#   'max_price_usd': 0.00198758334622,
#   'max_price_btc': 3.4243465985749337e-07,
#   'max_price_usd_date': datetime.date(2019, 5, 11),
#   'max_price_btc_date': datetime.date(2019, 2, 4),
#   'current_price_usd': 0.000150840927608,
#   'current_price_btc': 2.1108046626838154e-08,
#   'max_price_usd_days_after_launch': 100,
#   'max_price_btc_days_after_launch': 0},
#  'FIII': {'id': 3655,
#   'name': 'Fiii',
#   'date_added': datetime.date(2019, 1, 1),
#   'date_start': datetime.date(2019, 2, 5),
#   'starting_price_usd': 0.0189874974839,
#   'starting_price_btc': 5.477651343567507e-06,
#   'max_price_usd': 0.0266208644149,
#   'max_price_btc': 5.477651343567507e-06,
#   'max_price_usd_date': datetime.date(2019, 5, 8),
#   'max_price_btc_date': datetime.date(2019, 2, 5),
#   'current_price_usd': 0.00105137738382,
#   'current_price_btc': 1.435917906007782e-07,
#   'max_price_usd_days_after_launch': 127,
#   'max_price_btc_days_after_launch': 0},
#  'HEDG': {'id': 3662,
#   'name': 'HedgeTrade',
#   'date_added': datetime.date(2019, 1, 3),
#   'date_start': datetime.date(2019, 2, 5),
#   'starting_price_usd': 0.117761846811,
#   'starting_price_btc': 3.3972793884619453e-05,
#   'max_price_usd': 1.22132764822,
#   'max_price_btc': 0.00016717990795485352,
#   'max_price_usd_date': datetime.date(2019, 12, 8),
#   'max_price_btc_date': datetime.date(2019, 12, 11),
#   'current_price_usd': 1.20660880079,
#   'current_price_btc': 0.00016717990795485352,
#   'max_price_usd_days_after_launch': 339,
#   'max_price_btc_days_after_launch': 342},
#  'HYN': {'id': 3695,
#   'name': 'Hyperion',
#   'date_added': datetime.date(2019, 1, 14),
#   'date_start': datetime.date(2019, 2, 5),
#   'starting_price_usd': 0.0260825400058,
#   'starting_price_btc': 7.524480802568521e-06,
#   'max_price_usd': 0.123040538285,
#   'max_price_btc': 1.0832309383923276e-05,
#   'max_price_usd_date': datetime.date(2019, 7, 11),
#   'max_price_btc_date': datetime.date(2019, 7, 11),
#   'current_price_usd': 0.0720359337454,
#   'current_price_btc': 9.980832864067493e-06,
#   'max_price_usd_days_after_launch': 178,
#   'max_price_btc_days_after_launch': 178},
#  'SDA': {'id': 3710,
#   'name': 'SDChain',
#   'date_added': datetime.date(2019, 1, 28),
#   'date_start': datetime.date(2019, 2, 5),
#   'starting_price_usd': 0.00434275266937,
#   'starting_price_btc': 1.2528288688030904e-06,
#   'max_price_usd': 0.0083297037956,
#   'max_price_btc': 2.028976112628079e-06,
#   'max_price_usd_date': datetime.date(2019, 4, 8),
#   'max_price_btc_date': datetime.date(2019, 3, 5),
#   'current_price_usd': 0.00116360003293,
#   'current_price_btc': 1.6122089137269462e-07,
#   'max_price_usd_days_after_launch': 70,
#   'max_price_btc_days_after_launch': 36},
#  'BEAM': {'id': 3702,
#   'name': 'Beam',
#   'date_added': datetime.date(2019, 1, 17),
#   'date_start': datetime.date(2019, 2, 5),
#   'starting_price_usd': 1.46140777642,
#   'starting_price_btc': 0.00042159754210868163,
#   'max_price_usd': 2.28802955813,
#   'max_price_btc': 0.00042159754210868163,
#   'max_price_usd_date': datetime.date(2019, 6, 23),
#   'max_price_btc_date': datetime.date(2019, 2, 5),
#   'current_price_usd': 0.543594215057,
#   'current_price_btc': 7.5316897057704e-05,
#   'max_price_usd_days_after_launch': 157,
#   'max_price_btc_days_after_launch': 0},
#  'LAMB': {'id': 3657,
#   'name': 'Lambda',
#   'date_added': datetime.date(2019, 1, 2),
#   'date_start': datetime.date(2019, 2, 5),
#   'starting_price_usd': 0.0128127444194,
#   'starting_price_btc': 3.696313679210446e-06,
#   'max_price_usd': 0.262137974835,
#   'max_price_btc': 2.9919833235430664e-05,
#   'max_price_usd_date': datetime.date(2019, 7, 9),
#   'max_price_btc_date': datetime.date(2019, 4, 11),
#   'current_price_usd': 0.0306885879588,
#   'current_price_btc': 4.252012174001649e-06,
#   'max_price_usd_days_after_launch': 188,
#   'max_price_btc_days_after_launch': 99},
#  'ADM': {'id': 3703,
#   'name': 'ADAMANT Messenger',
#   'date_added': datetime.date(2019, 1, 17),
#   'date_start': datetime.date(2019, 2, 5),
#   'starting_price_usd': 0.0390819569657,
#   'starting_price_btc': 1.1274647133669718e-05,
#   'max_price_usd': 0.0545314945825,
#   'max_price_btc': 1.1274647133669718e-05,
#   'max_price_usd_date': datetime.date(2019, 5, 15),
#   'max_price_btc_date': datetime.date(2019, 2, 5),
#   'current_price_usd': 0.0110344869176,
#   'current_price_btc': 1.5074136115510643e-06,
#   'max_price_usd_days_after_launch': 118,
#   'max_price_btc_days_after_launch': 0},
#  'CTX': {'id': 3700,
#   'name': 'Centauri',
#   'date_added': datetime.date(2019, 1, 16),
#   'date_start': datetime.date(2019, 2, 5),
#   'starting_price_usd': 0.0189984235353,
#   'starting_price_btc': 5.480803370325212e-06,
#   'max_price_usd': 0.0189984235353,
#   'max_price_btc': 5.480803370325212e-06,
#   'max_price_usd_date': datetime.date(2019, 2, 5),
#   'max_price_btc_date': datetime.date(2019, 2, 5),
#   'current_price_usd': 0.00788028622934,
#   'current_price_btc': 8.497619812693965e-07,
#   'max_price_usd_days_after_launch': 0,
#   'max_price_btc_days_after_launch': 0},
#  'CAJ': {'id': 3715,
#   'name': 'Cajutel',
#   'date_added': datetime.date(2019, 1, 31),
#   'date_start': datetime.date(2019, 2, 5),
#   'starting_price_usd': 1.21307680583,
#   'starting_price_btc': 0.0003499572179503693,
#   'max_price_usd': 37.5240123612,
#   'max_price_btc': 0.00922168204966561,
#   'max_price_usd_date': datetime.date(2019, 3, 28),
#   'max_price_btc_date': datetime.date(2019, 3, 28),
#   'current_price_usd': 2.07591065617,
#   'current_price_btc': 0.00028762474813193525,
#   'max_price_usd_days_after_launch': 56,
#   'max_price_btc_days_after_launch': 56},
#  'CLB': {'id': 3712,
#   'name': 'Cloudbric',
#   'date_added': datetime.date(2019, 1, 29),
#   'date_start': datetime.date(2019, 2, 7),
#   'starting_price_usd': 0.00438712351434,
#   'starting_price_btc': 1.2905309925477107e-06,
#   'max_price_usd': 0.0103774765849,
#   'max_price_btc': 2.3114150983579154e-06,
#   'max_price_usd_date': datetime.date(2019, 6, 6),
#   'max_price_btc_date': datetime.date(2019, 3, 26),
#   'current_price_usd': 0.0012262580755,
#   'current_price_btc': 1.6990238431607902e-07,
#   'max_price_usd_days_after_launch': 128,
#   'max_price_btc_days_after_launch': 56},
#  'SPND': {'id': 3307,
#   'name': 'Spendcoin',
#   'date_added': datetime.date(2019, 1, 30),
#   'date_start': datetime.date(2019, 2, 11),
#   'starting_price_usd': 0.304168222067,
#   'starting_price_btc': 8.336960548306089e-05,
#   'max_price_usd': 0.361794885589,
#   'max_price_btc': 9.96111929437831e-05,
#   'max_price_usd_date': datetime.date(2019, 2, 13),
#   'max_price_btc_date': datetime.date(2019, 2, 13),
#   'current_price_usd': 0.00151948929919,
#   'current_price_btc': 2.105306052886817e-07,
#   'max_price_usd_days_after_launch': 14,
#   'max_price_btc_days_after_launch': 14},
#  'LTO': {'id': 3714,
#   'name': 'LTO Network',
#   'date_added': datetime.date(2019, 2, 5),
#   'date_start': datetime.date(2019, 2, 11),
#   'starting_price_usd': 0.07225326511,
#   'starting_price_btc': 1.9803930095487902e-05,
#   'max_price_usd': 0.222584192239,
#   'max_price_btc': 5.738708244961862e-05,
#   'max_price_usd_date': datetime.date(2019, 2, 25),
#   'max_price_btc_date': datetime.date(2019, 2, 24),
#   'current_price_usd': 0.0243596330214,
#   'current_price_btc': 3.3751131300097617e-06,
#   'max_price_usd_days_after_launch': 20,
#   'max_price_btc_days_after_launch': 19},
#  'S4F': {'id': 3733,
#   'name': 'S4FE',
#   'date_added': datetime.date(2019, 2, 7),
#   'date_start': datetime.date(2019, 2, 11),
#   'starting_price_usd': 0.254588764016,
#   'starting_price_btc': 6.978034941388034e-05,
#   'max_price_usd': 2.38579168264,
#   'max_price_btc': 0.0006144677570330782,
#   'max_price_usd_date': datetime.date(2019, 2, 25),
#   'max_price_btc_date': datetime.date(2019, 2, 25),
#   'current_price_usd': 0.0329416245949,
#   'current_price_btc': 4.564178351801363e-06,
#   'max_price_usd_days_after_launch': 18,
#   'max_price_btc_days_after_launch': 18},
#  'WCO': {'id': 3669,
#   'name': 'Winco',
#   'date_added': datetime.date(2019, 1, 4),
#   'date_start': datetime.date(2019, 2, 11),
#   'starting_price_usd': 0.00404700603152,
#   'starting_price_btc': 1.109245712594759e-06,
#   'max_price_usd': 0.00514874853932,
#   'max_price_btc': 1.2787888841432528e-06,
#   'max_price_usd_date': datetime.date(2019, 6, 14),
#   'max_price_btc_date': datetime.date(2019, 3, 11),
#   'current_price_usd': 0.00290702497766,
#   'current_price_btc': 3.8951944775870193e-07,
#   'max_price_usd_days_after_launch': 161,
#   'max_price_btc_days_after_launch': 66},
#  'HALO': {'id': 3728,
#   'name': 'Halo Platform',
#   'date_added': datetime.date(2019, 2, 7),
#   'date_start': datetime.date(2019, 2, 12),
#   'starting_price_usd': 0.00121870750509,
#   'starting_price_btc': 3.3356998767967977e-07,
#   'max_price_usd': 0.00233786755873,
#   'max_price_btc': 6.440783556287952e-07,
#   'max_price_usd_date': datetime.date(2019, 2, 16),
#   'max_price_btc_date': datetime.date(2019, 2, 16),
#   'current_price_usd': 0.000427782469998,
#   'current_price_btc': 5.927077103377799e-08,
#   'max_price_usd_days_after_launch': 9,
#   'max_price_btc_days_after_launch': 9},
#  'GRIN': {'id': 3709,
#   'name': 'Grin',
#   'date_added': datetime.date(2019, 1, 27),
#   'date_start': datetime.date(2019, 2, 13),
#   'starting_price_usd': 5.0068539262,
#   'starting_price_btc': 0.0013785122796086582,
#   'max_price_usd': 6.40125811608,
#   'max_price_btc': 0.0014567133272467329,
#   'max_price_usd_date': datetime.date(2019, 6, 23),
#   'max_price_btc_date': datetime.date(2019, 2, 14),
#   'current_price_usd': 1.166191886,
#   'current_price_btc': 0.00016158000176323,
#   'max_price_usd_days_after_launch': 147,
#   'max_price_btc_days_after_launch': 18},
#  'USDS': {'id': 3719,
#   'name': 'StableUSD',
#   'date_added': datetime.date(2019, 2, 5),
#   'date_start': datetime.date(2019, 2, 13),
#   'starting_price_usd': 1.01512536277,
#   'starting_price_btc': 0.0002794894355910836,
#   'max_price_usd': 1.05425415093,
#   'max_price_btc': 0.00027999925966355483,
#   'max_price_usd_date': datetime.date(2019, 11, 13),
#   'max_price_btc_date': datetime.date(2019, 2, 14),
#   'current_price_usd': 1.00717385551,
#   'current_price_btc': 0.00013954749240056448,
#   'max_price_usd_days_after_launch': 281,
#   'max_price_btc_days_after_launch': 9},
#  'BLCR': {'id': 3740,
#   'name': 'Blacer Coin',
#   'date_added': datetime.date(2019, 2, 12),
#   'date_start': datetime.date(2019, 2, 13),
#   'starting_price_usd': 15.5480157816,
#   'starting_price_btc': 0.004280758135628632,
#   'max_price_usd': 18.4477518665,
#   'max_price_btc': 0.004786206204512852,
#   'max_price_usd_date': datetime.date(2019, 2, 26),
#   'max_price_btc_date': datetime.date(2019, 2, 26),
#   'current_price_usd': 2.18794536833,
#   'current_price_btc': 0.0005437283001238633,
#   'max_price_usd_days_after_launch': 14,
#   'max_price_btc_days_after_launch': 14},
#  'AEN': {'id': 3683,
#   'name': 'Aencoin',
#   'date_added': datetime.date(2019, 1, 9),
#   'date_start': datetime.date(2019, 2, 13),
#   'starting_price_usd': 0.0108033671182,
#   'starting_price_btc': 2.974437531646138e-06,
#   'max_price_usd': 0.0496796358869,
#   'max_price_btc': 4.840001561361564e-06,
#   'max_price_usd_date': datetime.date(2019, 7, 8),
#   'max_price_btc_date': datetime.date(2019, 7, 16),
#   'current_price_usd': 0.0252631283415,
#   'current_price_btc': 3.5002955954062226e-06,
#   'max_price_usd_days_after_launch': 180,
#   'max_price_btc_days_after_launch': 188},
#  'CCX': {'id': 3732,
#   'name': 'Conceal',
#   'date_added': datetime.date(2019, 2, 8),
#   'date_start': datetime.date(2019, 2, 15),
#   'starting_price_usd': 0.195969631326,
#   'starting_price_btc': 5.4123135591041064e-05,
#   'max_price_usd': 0.839598659358,
#   'max_price_btc': 8.82010494396103e-05,
#   'max_price_usd_date': datetime.date(2019, 7, 29),
#   'max_price_btc_date': datetime.date(2019, 7, 29),
#   'current_price_usd': 0.0983960300458,
#   'current_price_btc': 1.3633117241818294e-05,
#   'max_price_usd_days_after_launch': 171,
#   'max_price_btc_days_after_launch': 171},
#  'SOLVE': {'id': 3724,
#   'name': 'SOLVE',
#   'date_added': datetime.date(2019, 2, 4),
#   'date_start': datetime.date(2019, 2, 19),
#   'starting_price_usd': 0.0537964508284,
#   'starting_price_btc': 1.362938032058594e-05,
#   'max_price_usd': 0.514699805854,
#   'max_price_btc': 6.578279327240245e-05,
#   'max_price_usd_date': datetime.date(2019, 6, 5),
#   'max_price_btc_date': datetime.date(2019, 6, 5),
#   'current_price_usd': 0.105869829917,
#   'current_price_btc': 1.4668638592004164e-05,
#   'max_price_usd_days_after_launch': 121,
#   'max_price_btc_days_after_launch': 121},
#  'PLA': {'id': 3731,
#   'name': 'PlayChip',
#   'date_added': datetime.date(2019, 2, 8),
#   'date_start': datetime.date(2019, 2, 19),
#   'starting_price_usd': 0.00164009500807,
#   'starting_price_btc': 4.155195795013254e-07,
#   'max_price_usd': 0.318975917122,
#   'max_price_btc': 4.376166077052205e-05,
#   'max_price_usd_date': datetime.date(2019, 11, 30),
#   'max_price_btc_date': datetime.date(2019, 12, 10),
#   'current_price_usd': 3.93702817352e-05,
#   'current_price_btc': 5.454891487894024e-09,
#   'max_price_usd_days_after_launch': 295,
#   'max_price_btc_days_after_launch': 305},
#  'VEO': {'id': 3716,
#   'name': 'Amoveo',
#   'date_added': datetime.date(2019, 2, 5),
#   'date_start': datetime.date(2019, 2, 19),
#   'starting_price_usd': 66.2758196428,
#   'starting_price_btc': 0.01679103989316366,
#   'max_price_usd': 166.694118741,
#   'max_price_btc': 0.03650325308526265,
#   'max_price_usd_date': datetime.date(2019, 7, 21),
#   'max_price_btc_date': datetime.date(2019, 3, 27),
#   'current_price_usd': 39.0760934607,
#   'current_price_btc': 0.005246305063447905,
#   'max_price_usd_days_after_launch': 166,
#   'max_price_btc_days_after_launch': 50},
#  'BTU': {'id': 3737,
#   'name': 'BTU Protocol',
#   'date_added': datetime.date(2019, 2, 11),
#   'date_start': datetime.date(2019, 2, 19),
#   'starting_price_usd': 0.165718829737,
#   'starting_price_btc': 4.198501800746352e-05,
#   'max_price_usd': 0.421615179856,
#   'max_price_btc': 6.171704248468922e-05,
#   'max_price_usd_date': datetime.date(2019, 6, 28),
#   'max_price_btc_date': datetime.date(2019, 3, 8),
#   'current_price_usd': 0.130729656434,
#   'current_price_btc': 1.8113055296212353e-05,
#   'max_price_usd_days_after_launch': 137,
#   'max_price_btc_days_after_launch': 25},
#  'KT': {'id': 3691,
#   'name': 'Kuai Token',
#   'date_added': datetime.date(2019, 1, 11),
#   'date_start': datetime.date(2019, 2, 21),
#   'starting_price_usd': 0.142556779121,
#   'starting_price_btc': 3.6052735489777866e-05,
#   'max_price_usd': 0.153016269548,
#   'max_price_btc': 3.898940765894568e-05,
#   'max_price_usd_date': datetime.date(2019, 2, 22),
#   'max_price_btc_date': datetime.date(2019, 3, 5),
#   'current_price_usd': 0.138714639759,
#   'current_price_btc': 1.9219402918093218e-05,
#   'max_price_usd_days_after_launch': 42,
#   'max_price_btc_days_after_launch': 53},
#  'EVY': {'id': 3754,
#   'name': 'EveryCoin ',
#   'date_added': datetime.date(2019, 2, 20),
#   'date_start': datetime.date(2019, 2, 25),
#   'starting_price_usd': 0.00035054837545,
#   'starting_price_btc': 9.028477865929983e-08,
#   'max_price_usd': 0.000596756585669,
#   'max_price_btc': 1.1118871803107309e-07,
#   'max_price_usd_date': datetime.date(2019, 6, 17),
#   'max_price_btc_date': datetime.date(2019, 3, 28),
#   'current_price_usd': 0.00022656262098,
#   'current_price_btc': 3.139105076694935e-08,
#   'max_price_usd_days_after_launch': 117,
#   'max_price_btc_days_after_launch': 36},
#  'VGW': {'id': 3735,
#   'name': 'VegaWallet Token',
#   'date_added': datetime.date(2019, 2, 11),
#   'date_start': datetime.date(2019, 2, 25),
#   'starting_price_usd': 0.117600773895,
#   'starting_price_btc': 3.0288429742806955e-05,
#   'max_price_usd': 0.219911707022,
#   'max_price_btc': 3.628579493441857e-05,
#   'max_price_usd_date': datetime.date(2019, 9, 4),
#   'max_price_btc_date': datetime.date(2019, 4, 23),
#   'current_price_usd': 0.0806758402406,
#   'current_price_btc': 1.1084709051603499e-05,
#   'max_price_usd_days_after_launch': 205,
#   'max_price_btc_days_after_launch': 71},
#  'MNC': {'id': 3755,
#   'name': 'Moneynet',
#   'date_added': datetime.date(2019, 2, 19),
#   'date_start': datetime.date(2019, 2, 25),
#   'starting_price_usd': 0.000184412978027,
#   'starting_price_btc': 4.7496112003647906e-08,
#   'max_price_usd': 0.0149289902879,
#   'max_price_btc': 3.7088549156676824e-06,
#   'max_price_usd_date': datetime.date(2019, 3, 17),
#   'max_price_btc_date': datetime.date(2019, 3, 17),
#   'current_price_usd': 0.00146450149658,
#   'current_price_btc': 1.9488561764149646e-07,
#   'max_price_usd_days_after_launch': 26,
#   'max_price_btc_days_after_launch': 26},
#  'MPG': {'id': 3758,
#   'name': 'Max Property Group',
#   'date_added': datetime.date(2019, 2, 22),
#   'date_start': datetime.date(2019, 2, 25),
#   'starting_price_usd': 0.00899789161777,
#   'starting_price_btc': 2.317433798025418e-06,
#   'max_price_usd': 0.0221221269087,
#   'max_price_btc': 2.7048134375338576e-06,
#   'max_price_usd_date': datetime.date(2019, 6, 19),
#   'max_price_btc_date': datetime.date(2019, 3, 6),
#   'current_price_usd': 0.0033096721714,
#   'current_price_btc': 4.585667605052478e-07,
#   'max_price_usd_days_after_launch': 117,
#   'max_price_btc_days_after_launch': 12},
#  'PLTC': {'id': 3753,
#   'name': 'PlatonCoin',
#   'date_added': datetime.date(2019, 2, 20),
#   'date_start': datetime.date(2019, 2, 25),
#   'starting_price_usd': 0.186574301265,
#   'starting_price_btc': 4.805276724389409e-05,
#   'max_price_usd': 0.506248705781,
#   'max_price_btc': 9.554772614887245e-05,
#   'max_price_usd_date': datetime.date(2019, 4, 18),
#   'max_price_btc_date': datetime.date(2019, 4, 18),
#   'current_price_usd': 0.284770194589,
#   'current_price_btc': 3.9455915528300945e-05,
#   'max_price_usd_days_after_launch': 57,
#   'max_price_btc_days_after_launch': 57},
#  'ELD': {'id': 3746,
#   'name': 'electrumdark',
#   'date_added': datetime.date(2019, 2, 18),
#   'date_start': datetime.date(2019, 2, 26),
#   'starting_price_usd': 1.36803356066,
#   'starting_price_btc': 0.00035493163413060166,
#   'max_price_usd': 1.36803356066,
#   'max_price_btc': 0.0003552367421702503,
#   'max_price_usd_date': datetime.date(2019, 2, 26),
#   'max_price_btc_date': datetime.date(2019, 2, 27),
#   'current_price_usd': 0.42649710447,
#   'current_price_btc': 3.985324412299961e-05,
#   'max_price_usd_days_after_launch': 0,
#   'max_price_btc_days_after_launch': 9},
#  'XPC': {'id': 3750,
#   'name': 'eXPerience Chain',
#   'date_added': datetime.date(2019, 2, 25),
#   'date_start': datetime.date(2019, 2, 27),
#   'starting_price_usd': 3.89137965606e-05,
#   'starting_price_btc': 1.0104730405147598e-08,
#   'max_price_usd': 4.30828112404e-05,
#   'max_price_btc': 1.0104730405147598e-08,
#   'max_price_usd_date': datetime.date(2019, 4, 10),
#   'max_price_btc_date': datetime.date(2019, 2, 27),
#   'current_price_usd': 7.99124002294e-06,
#   'current_price_btc': 1.1072145094628444e-09,
#   'max_price_usd_days_after_launch': 44,
#   'max_price_btc_days_after_launch': 0},
#  'SWC': {'id': 3760,
#   'name': 'Scanetchain',
#   'date_added': datetime.date(2019, 2, 22),
#   'date_start': datetime.date(2019, 2, 27),
#   'starting_price_usd': 0.00292836684516,
#   'starting_price_btc': 7.604078787746574e-07,
#   'max_price_usd': 0.00478851168605,
#   'max_price_btc': 1.0782494791231987e-06,
#   'max_price_usd_date': datetime.date(2019, 4, 9),
#   'max_price_btc_date': datetime.date(2019, 3, 17),
#   'current_price_usd': 0.000820540138524,
#   'current_price_btc': 8.148045576125333e-08,
#   'max_price_usd_days_after_launch': 46,
#   'max_price_btc_days_after_launch': 23},
#  'LABX': {'id': 3751,
#   'name': 'Stakinglab',
#   'date_added': datetime.date(2019, 2, 25),
#   'date_start': datetime.date(2019, 2, 27),
#   'starting_price_usd': 1.47787266009,
#   'starting_price_btc': 0.00038375861836282193,
#   'max_price_usd': 3.97656776648,
#   'max_price_btc': 0.001018603035708704,
#   'max_price_usd_date': datetime.date(2019, 3, 6),
#   'max_price_btc_date': datetime.date(2019, 3, 6),
#   'current_price_usd': 1.30415715935,
#   'current_price_btc': 0.00015894339270589516,
#   'max_price_usd_days_after_launch': 9,
#   'max_price_btc_days_after_launch': 9},
#  'SNPC': {'id': 3679,
#   'name': 'SnapCoin',
#   'date_added': datetime.date(2019, 1, 8),
#   'date_start': datetime.date(2019, 2, 28),
#   'starting_price_usd': 0.00529493842662,
#   'starting_price_btc': 1.3736013912979632e-06,
#   'max_price_usd': 0.024586744879,
#   'max_price_btc': 6.39085573430347e-06,
#   'max_price_usd_date': datetime.date(2019, 3, 3),
#   'max_price_btc_date': datetime.date(2019, 3, 3),
#   'current_price_usd': 0.000653510432535,
#   'current_price_btc': 8.18057818109026e-08,
#   'max_price_usd_days_after_launch': 54,
#   'max_price_btc_days_after_launch': 54},
#  'GMB': {'id': 3757,
#   'name': 'GMB',
#   'date_added': datetime.date(2019, 2, 22),
#   'date_start': datetime.date(2019, 2, 28),
#   'starting_price_usd': 0.00352686843084,
#   'starting_price_btc': 9.149325248375288e-07,
#   'max_price_usd': 0.00685300129479,
#   'max_price_btc': 1.7496868535318668e-06,
#   'max_price_usd_date': datetime.date(2019, 3, 9),
#   'max_price_btc_date': datetime.date(2019, 3, 4),
#   'current_price_usd': 0.000169481444099,
#   'current_price_btc': 2.3482252247767042e-08,
#   'max_price_usd_days_after_launch': 15,
#   'max_price_btc_days_after_launch': 10},
#  'SHMN': {'id': 3480,
#   'name': 'StrongHands Masternode',
#   'date_added': datetime.date(2019, 1, 8),
#   'date_start': datetime.date(2019, 2, 28),
#   'starting_price_usd': 0.383143730807,
#   'starting_price_btc': 9.939431194472648e-05,
#   'max_price_usd': 1.12186589768,
#   'max_price_btc': 0.0001150109920651633,
#   'max_price_usd_date': datetime.date(2019, 8, 28),
#   'max_price_btc_date': datetime.date(2019, 8, 28),
#   'current_price_usd': 0.468053572312,
#   'current_price_btc': 5.624963935384239e-05,
#   'max_price_usd_days_after_launch': 232,
#   'max_price_btc_days_after_launch': 232},
#  'UPX': {'id': 3752,
#   'name': 'uPlexa',
#   'date_added': datetime.date(2019, 2, 19),
#   'date_start': datetime.date(2019, 2, 28),
#   'starting_price_usd': 0.000237138814999,
#   'starting_price_btc': 6.151803476613942e-08,
#   'max_price_usd': 0.00103301899512,
#   'max_price_btc': 1.7370413717926317e-07,
#   'max_price_usd_date': datetime.date(2019, 6, 21),
#   'max_price_btc_date': datetime.date(2019, 4, 16),
#   'current_price_usd': 0.000104784447201,
#   'current_price_btc': 1.3852414401472503e-08,
#   'max_price_usd_days_after_launch': 122,
#   'max_price_btc_days_after_launch': 56},
#  'MHC': {'id': 3756,
#   'name': '#MetaHash',
#   'date_added': datetime.date(2019, 2, 21),
#   'date_start': datetime.date(2019, 3, 4),
#   'starting_price_usd': 0.0305196199799,
#   'starting_price_btc': 8.113560376846134e-06,
#   'max_price_usd': 0.096977434717,
#   'max_price_btc': 2.361467292587694e-05,
#   'max_price_usd_date': datetime.date(2019, 3, 30),
#   'max_price_btc_date': datetime.date(2019, 3, 30),
#   'current_price_usd': 0.00340807188018,
#   'current_price_btc': 4.7220038744867323e-07,
#   'max_price_usd_days_after_launch': 37,
#   'max_price_btc_days_after_launch': 37},
#  'GBT': {'id': 3674,
#   'name': 'Globatalent',
#   'date_added': datetime.date(2019, 1, 11),
#   'date_start': datetime.date(2019, 3, 4),
#   'starting_price_usd': 0.00720685522915,
#   'starting_price_btc': 1.915923431137343e-06,
#   'max_price_usd': 0.00724825556611,
#   'max_price_btc': 1.915923431137343e-06,
#   'max_price_usd_date': datetime.date(2019, 3, 6),
#   'max_price_btc_date': datetime.date(2019, 3, 4),
#   'current_price_usd': 0.000676192194227,
#   'current_price_btc': 7.305330098727879e-08,
#   'max_price_usd_days_after_launch': 54,
#   'max_price_btc_days_after_launch': 0},
#  'OWC': {'id': 3763,
#   'name': 'ODUWA',
#   'date_added': datetime.date(2019, 2, 25),
#   'date_start': datetime.date(2019, 3, 4),
#   'starting_price_usd': 0.554074392617,
#   'starting_price_btc': 0.00014729921410302926,
#   'max_price_usd': 0.564163185466,
#   'max_price_btc': 0.00014729921410302926,
#   'max_price_usd_date': datetime.date(2019, 3, 6),
#   'max_price_btc_date': datetime.date(2019, 3, 4),
#   'current_price_usd': 0.129138435341,
#   'current_price_btc': 1.7892585997721085e-05,
#   'max_price_usd_days_after_launch': 9,
#   'max_price_btc_days_after_launch': 0},
#  'WLO': {'id': 3729,
#   'name': 'WOLLO',
#   'date_added': datetime.date(2019, 2, 6),
#   'date_start': datetime.date(2019, 3, 4),
#   'starting_price_usd': 0.0459402633659,
#   'starting_price_btc': 1.2213097698887652e-05,
#   'max_price_usd': 0.0823320359595,
#   'max_price_btc': 1.2213097698887652e-05,
#   'max_price_usd_date': datetime.date(2019, 5, 24),
#   'max_price_btc_date': datetime.date(2019, 3, 4),
#   'current_price_usd': 0.00742588327714,
#   'current_price_btc': 1.0288823369620163e-06,
#   'max_price_usd_days_after_launch': 107,
#   'max_price_btc_days_after_launch': 0},
#  'SCC': {'id': 3772,
#   'name': 'STEM CELL COIN',
#   'date_added': datetime.date(2019, 3, 1),
#   'date_start': datetime.date(2019, 3, 6),
#   'starting_price_usd': 0.0479438481752,
#   'starting_price_btc': 1.2280879432376584e-05,
#   'max_price_usd': 1.03427161389,
#   'max_price_btc': 0.00011160127222075698,
#   'max_price_usd_date': datetime.date(2019, 11, 7),
#   'max_price_btc_date': datetime.date(2019, 11, 7),
#   'current_price_usd': 0.00212001981827,
#   'current_price_btc': 2.937362282197778e-07,
#   'max_price_usd_days_after_launch': 251,
#   'max_price_btc_days_after_launch': 251},
#  'HBX': {'id': 3769,
#   'name': 'HashBX ',
#   'date_added': datetime.date(2019, 3, 1),
#   'date_start': datetime.date(2019, 3, 6),
#   'starting_price_usd': 0.304886600858,
#   'starting_price_btc': 7.809710167614435e-05,
#   'max_price_usd': 0.304886600858,
#   'max_price_btc': 7.809710167614435e-05,
#   'max_price_usd_date': datetime.date(2019, 3, 6),
#   'max_price_btc_date': datetime.date(2019, 3, 6),
#   'current_price_usd': 0.00303993850107,
#   'current_price_btc': 4.211942084829437e-07,
#   'max_price_usd_days_after_launch': 0,
#   'max_price_btc_days_after_launch': 0},
#  'BTT': {'id': 3718,
#   'name': 'BitTorrent',
#   'date_added': datetime.date(2019, 1, 31),
#   'date_start': datetime.date(2019, 3, 13),
#   'starting_price_usd': 0.000755622407847,
#   'starting_price_btc': 1.93416204767062e-07,
#   'max_price_usd': 0.00177940522386,
#   'max_price_btc': 2.144900528525775e-07,
#   'max_price_usd_date': datetime.date(2019, 5, 28),
#   'max_price_btc_date': datetime.date(2019, 3, 17),
#   'current_price_usd': 0.000290823621517,
#   'current_price_btc': 4.0294639194141836e-08,
#   'max_price_usd_days_after_launch': 117,
#   'max_price_btc_days_after_launch': 45},
#  'SLOT': {'id': 3781,
#   'name': 'Alphaslot',
#   'date_added': datetime.date(2019, 3, 8),
#   'date_start': datetime.date(2019, 3, 14),
#   'starting_price_usd': 0.496644387827,
#   'starting_price_btc': 0.0001265539435495578,
#   'max_price_usd': 0.562225592806,
#   'max_price_btc': 0.00014194349891295753,
#   'max_price_usd_date': datetime.date(2019, 3, 15),
#   'max_price_btc_date': datetime.date(2019, 3, 15),
#   'current_price_usd': 0.118690734708,
#   'current_price_btc': 2.356526695831662e-05,
#   'max_price_usd_days_after_launch': 7,
#   'max_price_btc_days_after_launch': 7},
#  'ARAW': {'id': 3792,
#   'name': 'ARAW',
#   'date_added': datetime.date(2019, 3, 12),
#   'date_start': datetime.date(2019, 3, 14),
#   'starting_price_usd': 0.000125763626563,
#   'starting_price_btc': 3.2046839321550284e-08,
#   'max_price_usd': 0.00016180853347,
#   'max_price_btc': 3.2046839321550284e-08,
#   'max_price_usd_date': datetime.date(2019, 4, 10),
#   'max_price_btc_date': datetime.date(2019, 3, 14),
#   'current_price_usd': 0.00011394917392,
#   'current_price_btc': 1.9660956949580208e-08,
#   'max_price_usd_days_after_launch': 29,
#   'max_price_btc_days_after_launch': 0},
#  'NET': {'id': 3788,
#   'name': 'NEXT',
#   'date_added': datetime.date(2019, 3, 11),
#   'date_start': datetime.date(2019, 3, 17),
#   'starting_price_usd': 1.59645824994,
#   'starting_price_btc': 0.0003966130269873115,
#   'max_price_usd': 2.4371621125,
#   'max_price_btc': 0.0004859615913023526,
#   'max_price_usd_date': datetime.date(2019, 9, 8),
#   'max_price_btc_date': datetime.date(2019, 3, 18),
#   'current_price_usd': 0.70326305428,
#   'current_price_btc': 9.743957826729119e-05,
#   'max_price_usd_days_after_launch': 181,
#   'max_price_btc_days_after_launch': 7},
#  'SERV': {'id': 3765,
#   'name': 'Serve',
#   'date_added': datetime.date(2019, 2, 26),
#   'date_start': datetime.date(2019, 3, 17),
#   'starting_price_usd': 0.0843139020902,
#   'starting_price_btc': 2.0946361689297428e-05,
#   'max_price_usd': 0.0849308483714,
#   'max_price_btc': 2.106154812826622e-05,
#   'max_price_usd_date': datetime.date(2019, 3, 18),
#   'max_price_btc_date': datetime.date(2019, 3, 18),
#   'current_price_usd': 0.00480505124491,
#   'current_price_btc': 4.897153884632142e-07,
#   'max_price_usd_days_after_launch': 20,
#   'max_price_btc_days_after_launch': 20},
#  'SAFE': {'id': 3799,
#   'name': 'SafeCoin',
#   'date_added': datetime.date(2019, 3, 18),
#   'date_start': datetime.date(2019, 3, 21),
#   'starting_price_usd': 0.0428590407941,
#   'starting_price_btc': 1.0636774275873317e-05,
#   'max_price_usd': 1.24766871559,
#   'max_price_btc': 0.00011776577453475329,
#   'max_price_usd_date': datetime.date(2019, 9, 4),
#   'max_price_btc_date': datetime.date(2019, 9, 4),
#   'current_price_usd': 0.501334680619,
#   'current_price_btc': 6.946168941050784e-05,
#   'max_price_usd_days_after_launch': 170,
#   'max_price_btc_days_after_launch': 170},
#  'COT': {'id': 3779,
#   'name': 'CoTrader',
#   'date_added': datetime.date(2019, 3, 7),
#   'date_start': datetime.date(2019, 3, 21),
#   'starting_price_usd': 4.75523711044e-05,
#   'starting_price_btc': 1.1801566912101606e-08,
#   'max_price_usd': 0.000136118560133,
#   'max_price_btc': 2.775240522127245e-08,
#   'max_price_usd_date': datetime.date(2019, 4, 5),
#   'max_price_btc_date': datetime.date(2019, 3, 29),
#   'current_price_usd': 2.35154758828e-05,
#   'current_price_btc': 3.2581521790883193e-09,
#   'max_price_usd_days_after_launch': 29,
#   'max_price_btc_days_after_launch': 22},
#  'AID': {'id': 3785,
#   'name': 'AIDUS TOKEN',
#   'date_added': datetime.date(2019, 3, 7),
#   'date_start': datetime.date(2019, 3, 24),
#   'starting_price_usd': 0.00892869184419,
#   'starting_price_btc': 2.219870283325462e-06,
#   'max_price_usd': 0.0296385175519,
#   'max_price_btc': 3.7279821581175982e-06,
#   'max_price_usd_date': datetime.date(2019, 5, 15),
#   'max_price_btc_date': datetime.date(2019, 5, 16),
#   'current_price_usd': 0.00172746033493,
#   'current_price_btc': 2.31466671548391e-07,
#   'max_price_usd_days_after_launch': 69,
#   'max_price_btc_days_after_launch': 70},
#  'DCTO': {'id': 3738,
#   'name': 'Decentralized Crypto Token',
#   'date_added': datetime.date(2019, 2, 13),
#   'date_start': datetime.date(2019, 3, 24),
#   'starting_price_usd': 0.000614614101563,
#   'starting_price_btc': 1.5280666009996612e-07,
#   'max_price_usd': 0.00267090304618,
#   'max_price_btc': 2.1241790845596178e-07,
#   'max_price_usd_date': datetime.date(2019, 7, 9),
#   'max_price_btc_date': datetime.date(2019, 7, 9),
#   'current_price_usd': 0.00194986448098,
#   'current_price_btc': 1.7896727705923989e-07,
#   'max_price_usd_days_after_launch': 146,
#   'max_price_btc_days_after_launch': 146},
#  'TEMCO': {'id': 3722,
#   'name': 'TEMCO',
#   'date_added': datetime.date(2019, 2, 4),
#   'date_start': datetime.date(2019, 3, 24),
#   'starting_price_usd': 0.00221206329473,
#   'starting_price_btc': 5.499678629856011e-07,
#   'max_price_usd': 0.0044148481368,
#   'max_price_btc': 5.499678629856011e-07,
#   'max_price_usd_date': datetime.date(2019, 6, 27),
#   'max_price_btc_date': datetime.date(2019, 3, 24),
#   'current_price_usd': 0.000491994543168,
#   'current_price_btc': 6.816758040158837e-08,
#   'max_price_usd_days_after_launch': 143,
#   'max_price_btc_days_after_launch': 0},
#  'FET': {'id': 3773,
#   'name': 'Fetch',
#   'date_added': datetime.date(2019, 3, 2),
#   'date_start': datetime.date(2019, 3, 25),
#   'starting_price_usd': 0.201280273065,
#   'starting_price_btc': 5.078896911760023e-05,
#   'max_price_usd': 0.264814971076,
#   'max_price_btc': 5.423634165039728e-05,
#   'max_price_usd_date': datetime.date(2019, 5, 20),
#   'max_price_btc_date': datetime.date(2019, 3, 28),
#   'current_price_usd': 0.0539852574751,
#   'current_price_btc': 7.479847958756149e-06,
#   'max_price_usd_days_after_launch': 79,
#   'max_price_btc_days_after_launch': 26},
#  'ONOT': {'id': 3782,
#   'name': 'ONOToken',
#   'date_added': datetime.date(2019, 3, 7),
#   'date_start': datetime.date(2019, 3, 25),
#   'starting_price_usd': 0.00032549586484,
#   'starting_price_btc': 8.213223867162951e-08,
#   'max_price_usd': 0.000338954189216,
#   'max_price_btc': 8.293337326775708e-08,
#   'max_price_usd_date': datetime.date(2019, 3, 27),
#   'max_price_btc_date': datetime.date(2019, 3, 27),
#   'current_price_usd': 2.77789969407e-05,
#   'current_price_btc': 3.2384093459772565e-09,
#   'max_price_usd_days_after_launch': 20,
#   'max_price_btc_days_after_launch': 20},
#  'LUNES': {'id': 3786,
#   'name': 'Lunes',
#   'date_added': datetime.date(2019, 3, 14),
#   'date_start': datetime.date(2019, 3, 25),
#   'starting_price_usd': 0.00440542325525,
#   'starting_price_btc': 1.1116186512157351e-06,
#   'max_price_usd': 0.0170433083223,
#   'max_price_btc': 2.9769056253601633e-06,
#   'max_price_usd_date': datetime.date(2019, 7, 9),
#   'max_price_btc_date': datetime.date(2019, 4, 1),
#   'current_price_usd': 0.0016150682531,
#   'current_price_btc': 2.237734066892957e-07,
#   'max_price_usd_days_after_launch': 117,
#   'max_price_btc_days_after_launch': 18},
#  'OBSR': {'id': 3698,
#   'name': 'Observer',
#   'date_added': datetime.date(2019, 1, 15),
#   'date_start': datetime.date(2019, 3, 26),
#   'starting_price_usd': 0.00292527529176,
#   'starting_price_btc': 7.340567071195288e-07,
#   'max_price_usd': 0.00354805397676,
#   'max_price_btc': 7.340567071195288e-07,
#   'max_price_usd_date': datetime.date(2019, 4, 10),
#   'max_price_btc_date': datetime.date(2019, 3, 26),
#   'current_price_usd': 0.000833024293234,
#   'current_price_btc': 1.125571708505495e-07,
#   'max_price_usd_days_after_launch': 85,
#   'max_price_btc_days_after_launch': 0},
#  'NAVY': {'id': 3805,
#   'name': 'BoatPilot Token',
#   'date_added': datetime.date(2019, 3, 20),
#   'date_start': datetime.date(2019, 3, 27),
#   'starting_price_usd': 0.0159149895319,
#   'starting_price_btc': 3.893988655087569e-06,
#   'max_price_usd': 0.0164057282701,
#   'max_price_btc': 4.0317759317365995e-06,
#   'max_price_usd_date': datetime.date(2019, 3, 28),
#   'max_price_btc_date': datetime.date(2019, 3, 28),
#   'current_price_usd': 0.00700805461877,
#   'current_price_btc': 5.648317156258625e-07,
#   'max_price_usd_days_after_launch': 8,
#   'max_price_btc_days_after_launch': 8},
#  'OROX': {'id': 3808,
#   'name': 'Cointorox',
#   'date_added': datetime.date(2019, 3, 20),
#   'date_start': datetime.date(2019, 3, 27),
#   'starting_price_usd': 0.0877389285633,
#   'starting_price_btc': 2.146745945074088e-05,
#   'max_price_usd': 0.109993581213,
#   'max_price_btc': 2.146745945074088e-05,
#   'max_price_usd_date': datetime.date(2019, 6, 24),
#   'max_price_btc_date': datetime.date(2019, 3, 27),
#   'current_price_usd': 0.109993581213,
#   'current_price_btc': 9.98933410414177e-06,
#   'max_price_usd_days_after_launch': 96,
#   'max_price_btc_days_after_launch': 0},
#  'PIB': {'id': 3768,
#   'name': 'PIBBLE',
#   'date_added': datetime.date(2019, 2, 28),
#   'date_start': datetime.date(2019, 3, 28),
#   'starting_price_usd': 0.000638112944861,
#   'starting_price_btc': 1.5681890925311916e-07,
#   'max_price_usd': 0.000830876782395,
#   'max_price_btc': 1.5851316728204086e-07,
#   'max_price_usd_date': datetime.date(2019, 6, 26),
#   'max_price_btc_date': datetime.date(2019, 3, 29),
#   'current_price_usd': 0.000126163609939,
#   'current_price_btc': 1.7480413438924474e-08,
#   'max_price_usd_days_after_launch': 118,
#   'max_price_btc_days_after_launch': 29},
#  'CELR': {'id': 3814,
#   'name': 'Celer Network',
#   'date_added': datetime.date(2019, 3, 25),
#   'date_start': datetime.date(2019, 4, 3),
#   'starting_price_usd': 0.0189824660261,
#   'starting_price_btc': 3.81708883077969e-06,
#   'max_price_usd': 0.0209738461329,
#   'max_price_btc': 3.858991487354079e-06,
#   'max_price_usd_date': datetime.date(2019, 6, 11),
#   'max_price_btc_date': datetime.date(2019, 4, 4),
#   'current_price_usd': 0.0045252407562,
#   'current_price_btc': 6.269880781573507e-07,
#   'max_price_usd_days_after_launch': 78,
#   'max_price_btc_days_after_launch': 10},
#  'ANKR': {'id': 3783,
#   'name': 'Ankr Network',
#   'date_added': datetime.date(2019, 3, 6),
#   'date_start': datetime.date(2019, 4, 3),
#   'starting_price_usd': 0.0109275693411,
#   'starting_price_btc': 2.1973700794265627e-06,
#   'max_price_usd': 0.0114476332873,
#   'max_price_btc': 2.325431889622785e-06,
#   'max_price_usd_date': datetime.date(2019, 4, 4),
#   'max_price_btc_date': datetime.date(2019, 4, 4),
#   'current_price_usd': 0.00175612406146,
#   'current_price_btc': 2.4331718677997853e-07,
#   'max_price_usd_days_after_launch': 29,
#   'max_price_btc_days_after_launch': 29},
#  'TWINS': {'id': 3775,
#   'name': 'win.win',
#   'date_added': datetime.date(2019, 3, 11),
#   'date_start': datetime.date(2019, 4, 3),
#   'starting_price_usd': 0.00160050848429,
#   'starting_price_btc': 3.218382190465408e-07,
#   'max_price_usd': 0.00160050848429,
#   'max_price_btc': 3.218382190465408e-07,
#   'max_price_usd_date': datetime.date(2019, 4, 3),
#   'max_price_btc_date': datetime.date(2019, 4, 3),
#   'current_price_usd': 7.56069064143e-05,
#   'current_price_btc': 9.99516843616309e-09,
#   'max_price_usd_days_after_launch': 0,
#   'max_price_btc_days_after_launch': 0},
#  'RIF': {'id': 3701,
#   'name': 'RIF Token',
#   'date_added': datetime.date(2019, 1, 16),
#   'date_start': datetime.date(2019, 4, 4),
#   'starting_price_usd': 0.104268693452,
#   'starting_price_btc': 2.118077499141933e-05,
#   'max_price_usd': 0.158068043363,
#   'max_price_btc': 2.176583179121778e-05,
#   'max_price_usd_date': datetime.date(2019, 8, 23),
#   'max_price_btc_date': datetime.date(2019, 4, 5),
#   'current_price_usd': 0.0571098500377,
#   'current_price_btc': 7.912771286242139e-06,
#   'max_price_usd_days_after_launch': 219,
#   'max_price_btc_days_after_launch': 79},
#  'PTON': {'id': 3813,
#   'name': 'PTON',
#   'date_added': datetime.date(2019, 3, 25),
#   'date_start': datetime.date(2019, 4, 4),
#   'starting_price_usd': 0.00143443650114,
#   'starting_price_btc': 2.91386376526447e-07,
#   'max_price_usd': 0.00190614362486,
#   'max_price_btc': 3.751117067846675e-07,
#   'max_price_usd_date': datetime.date(2019, 4, 18),
#   'max_price_btc_date': datetime.date(2019, 4, 15),
#   'current_price_usd': 3.43226027564e-05,
#   'current_price_btc': 4.54784918175055e-09,
#   'max_price_usd_days_after_launch': 24,
#   'max_price_btc_days_after_launch': 21},
#  'XQR': {'id': 3821,
#   'name': 'Qredit',
#   'date_added': datetime.date(2019, 3, 28),
#   'date_start': datetime.date(2019, 4, 4),
#   'starting_price_usd': 0.002093715387,
#   'starting_price_btc': 4.2530996639498816e-07,
#   'max_price_usd': 0.0136475468199,
#   'max_price_btc': 2.5679680212791856e-06,
#   'max_price_usd_date': datetime.date(2019, 4, 21),
#   'max_price_btc_date': datetime.date(2019, 4, 21),
#   'current_price_usd': 0.000466491531813,
#   'current_price_btc': 6.463404816801855e-08,
#   'max_price_usd_days_after_launch': 24,
#   'max_price_btc_days_after_launch': 24},
#  'GPT': {'id': 3818,
#   'name': 'GoPower',
#   'date_added': datetime.date(2019, 3, 26),
#   'date_start': datetime.date(2019, 4, 6),
#   'starting_price_usd': 0.00494634575668,
#   'starting_price_btc': 9.775740057211285e-07,
#   'max_price_usd': 0.00603670678592,
#   'max_price_btc': 1.1412037949897603e-06,
#   'max_price_usd_date': datetime.date(2019, 4, 8),
#   'max_price_btc_date': datetime.date(2019, 4, 8),
#   'current_price_usd': 0.0034894631574,
#   'current_price_btc': 4.3682962317741845e-07,
#   'max_price_usd_days_after_launch': 13,
#   'max_price_btc_days_after_launch': 13},
#  'INNBCL': {'id': 3787,
#   'name': 'InnovativeBioresearchClassic',
#   'date_added': datetime.date(2019, 3, 13),
#   'date_start': datetime.date(2019, 4, 16),
#   'starting_price_usd': 3.66694416884e-07,
#   'starting_price_btc': 7.003920451330528e-11,
#   'max_price_usd': 3.66694416884e-07,
#   'max_price_btc': 7.003920451330528e-11,
#   'max_price_usd_date': datetime.date(2019, 4, 16),
#   'max_price_btc_date': datetime.date(2019, 4, 16),
#   'current_price_usd': 3.66694416884e-07,
#   'current_price_btc': 7.003920451330528e-11,
#   'max_price_usd_days_after_launch': 0,
#   'max_price_btc_days_after_launch': 0},
#  'TOP': {'id': 3826,
#   'name': 'TOP',
#   'date_added': datetime.date(2019, 3, 28),
#   'date_start': datetime.date(2019, 4, 17),
#   'starting_price_usd': 0.0140303928031,
#   'starting_price_btc': 2.671469522188026e-06,
#   'max_price_usd': 0.0142730450526,
#   'max_price_btc': 2.6938478744206333e-06,
#   'max_price_usd_date': datetime.date(2019, 4, 18),
#   'max_price_btc_date': datetime.date(2019, 4, 18),
#   'current_price_usd': 0.00153012385538,
#   'current_price_btc': 2.1200406058241147e-07,
#   'max_price_usd_days_after_launch': 21,
#   'max_price_btc_days_after_launch': 21},
#  'OVC': {'id': 3784,
#   'name': 'OVCODE',
#   'date_added': datetime.date(2019, 3, 7),
#   'date_start': datetime.date(2019, 4, 17),
#   'starting_price_usd': 0.223707134592,
#   'starting_price_btc': 4.259515755157601e-05,
#   'max_price_usd': 0.620873192361,
#   'max_price_btc': 0.00011361177372742377,
#   'max_price_usd_date': datetime.date(2019, 4, 24),
#   'max_price_btc_date': datetime.date(2019, 4, 24),
#   'current_price_usd': 0.0707665343743,
#   'current_price_btc': 9.56188308644186e-06,
#   'max_price_usd_days_after_launch': 48,
#   'max_price_btc_days_after_launch': 48},
# ...
#   'date_start': datetime.date(2019, 11, 11),
#   'starting_price_usd': 0.0678606893962,
#   'starting_price_btc': 7.74861017353225e-06,
#   'max_price_usd': 0.070556537799,
#   'max_price_btc': 8.368637454609143e-06,
#   'max_price_usd_date': datetime.date(2019, 11, 14),
#   'max_price_btc_date': datetime.date(2019, 11, 21),
#   'current_price_usd': 0.049446701342,
#   'current_price_btc': 6.851014988134009e-06,
#   'max_price_usd_days_after_launch': 310,
#   'max_price_btc_days_after_launch': 317},
#  'ANCT': {'id': 4901,
#   'name': 'Anchor',
#   'date_added': datetime.date(2019, 11, 9),
#   'date_start': datetime.date(2019, 11, 11),
#   'starting_price_usd': 0.792012909219,
#   'starting_price_btc': 9.043526289738624e-05,
#   'max_price_usd': 0.798815610023,
#   'max_price_btc': 0.00011319015513443247,
#   'max_price_usd_date': datetime.date(2019, 11, 15),
#   'max_price_btc_date': datetime.date(2019, 11, 24),
#   'current_price_usd': 0.79173972961,
#   'current_price_btc': 0.00010969833390386241,
#   'max_price_usd_days_after_launch': 6,
#   'max_price_btc_days_after_launch': 15},
#  'PAXG': {'id': 4705,
#   'name': 'PAX Gold',
#   'date_added': datetime.date(2019, 9, 26),
#   'date_start': datetime.date(2019, 11, 11),
#   'starting_price_usd': 1458.79403869,
#   'starting_price_btc': 0.16657105063118474,
#   'max_price_usd': 1559.51296266,
#   'max_price_btc': 0.212799568189931,
#   'max_price_usd_date': datetime.date(2019, 11, 16),
#   'max_price_btc_date': datetime.date(2019, 11, 26),
#   'current_price_usd': 1480.4162432,
#   'current_price_btc': 0.20511689547681378,
#   'max_price_usd_days_after_launch': 51,
#   'max_price_btc_days_after_launch': 61},
#  'EM': {'id': 4215,
#   'name': 'Eminer',
#   'date_added': datetime.date(2019, 8, 22),
#   'date_start': datetime.date(2019, 11, 11),
#   'starting_price_usd': 0.0139610769398,
#   'starting_price_btc': 1.5941326822898215e-06,
#   'max_price_usd': 0.0139610769398,
#   'max_price_btc': 1.5941326822898215e-06,
#   'max_price_usd_date': datetime.date(2019, 11, 11),
#   'max_price_btc_date': datetime.date(2019, 11, 11),
#   'current_price_usd': 0.00424846283719,
#   'current_price_btc': 5.886395206184597e-07,
#   'max_price_usd_days_after_launch': 0,
#   'max_price_btc_days_after_launch': 0},
#  'EBASE': {'id': 4815,
#   'name': 'EURBASE',
#   'date_added': datetime.date(2019, 10, 21),
#   'date_start': datetime.date(2019, 11, 11),
#   'starting_price_usd': 1.08804506685,
#   'starting_price_btc': 0.00012423742153623904,
#   'max_price_usd': 1.17611050351,
#   'max_price_btc': 0.00015803149632024282,
#   'max_price_usd_date': datetime.date(2019, 11, 29),
#   'max_price_btc_date': datetime.date(2019, 11, 25),
#   'current_price_usd': 1.11123018595,
#   'current_price_btc': 0.00015396486423946477,
#   'max_price_usd_days_after_launch': 39,
#   'max_price_btc_days_after_launch': 35},
#  'ILK': {'id': 4754,
#   'name': 'INLOCK',
#   'date_added': datetime.date(2019, 11, 1),
#   'date_start': datetime.date(2019, 11, 11),
#   'starting_price_usd': 0.00285814178058,
#   'starting_price_btc': 3.2635428073974026e-07,
#   'max_price_usd': 0.00291039716691,
#   'max_price_btc': 3.4977587705855525e-07,
#   'max_price_usd_date': datetime.date(2019, 11, 13),
#   'max_price_btc_date': datetime.date(2019, 11, 27),
#   'current_price_usd': 0.00216127857112,
#   'current_price_btc': 2.994527740457978e-07,
#   'max_price_usd_days_after_launch': 12,
#   'max_price_btc_days_after_launch': 26},
#  'EBK': {'id': 4778,
#   'name': 'ebakus',
#   'date_added': datetime.date(2019, 11, 9),
#   'date_start': datetime.date(2019, 11, 11),
#   'starting_price_usd': 0.00718503363646,
#   'starting_price_btc': 8.204164329601248e-07,
#   'max_price_usd': 0.00919429520062,
#   'max_price_btc': 1.3045408104080829e-06,
#   'max_price_usd_date': datetime.date(2019, 11, 24),
#   'max_price_btc_date': datetime.date(2019, 11, 24),
#   'current_price_usd': 0.00572927300923,
#   'current_price_btc': 7.938109963263878e-07,
#   'max_price_usd_days_after_launch': 15,
#   'max_price_btc_days_after_launch': 15},
#  'WIKEN': {'id': 4809,
#   'name': 'Project WITH',
#   'date_added': datetime.date(2019, 11, 9),
#   'date_start': datetime.date(2019, 11, 11),
#   'starting_price_usd': 0.00183988305524,
#   'starting_price_btc': 2.100853481859939e-07,
#   'max_price_usd': 0.00227741712424,
#   'max_price_btc': 3.1111637522386374e-07,
#   'max_price_usd_date': datetime.date(2019, 12, 3),
#   'max_price_btc_date': datetime.date(2019, 12, 3),
#   'current_price_usd': 0.00129943514367,
#   'current_price_btc': 1.8004132538219496e-07,
#   'max_price_usd_days_after_launch': 24,
#   'max_price_btc_days_after_launch': 24},
#  'BEST': {'id': 4361,
#   'name': 'Bitpanda Ecosystem Token',
#   'date_added': datetime.date(2019, 10, 18),
#   'date_start': datetime.date(2019, 11, 16),
#   'starting_price_usd': 0.0632134434366,
#   'starting_price_btc': 7.3927275843661025e-06,
#   'max_price_usd': 0.0647118197242,
#   'max_price_btc': 8.194768461255917e-06,
#   'max_price_usd_date': datetime.date(2019, 11, 20),
#   'max_price_btc_date': datetime.date(2019, 11, 24),
#   'current_price_usd': 0.0570549997222,
#   'current_price_btc': 7.905171581440899e-06,
#   'max_price_usd_days_after_launch': 33,
#   'max_price_btc_days_after_launch': 37},
#  'MGX': {'id': 4902,
#   'name': 'MargiX',
#   'date_added': datetime.date(2019, 11, 9),
#   'date_start': datetime.date(2019, 11, 27),
#   'starting_price_usd': 0.00562895883488,
#   'starting_price_btc': 7.473725727138402e-07,
#   'max_price_usd': 0.00642645306237,
#   'max_price_btc': 8.782452176455891e-07,
#   'max_price_usd_date': datetime.date(2019, 12, 8),
#   'max_price_btc_date': datetime.date(2019, 12, 11),
#   'current_price_usd': 0.00633867084763,
#   'current_price_btc': 8.782452176455891e-07,
#   'max_price_usd_days_after_launch': 29,
#   'max_price_btc_days_after_launch': 32},
#  'SFX': {'id': 4183,
#   'name': 'Safex Cash',
#   'date_added': datetime.date(2019, 11, 4),
#   'date_start': datetime.date(2019, 11, 28),
#   'starting_price_usd': 0.0494213349806,
#   'starting_price_btc': 6.622086585797695e-06,
#   'max_price_usd': 0.0494213349806,
#   'max_price_btc': 6.622086585797695e-06,
#   'max_price_usd_date': datetime.date(2019, 11, 28),
#   'max_price_btc_date': datetime.date(2019, 11, 28),
#   'current_price_usd': 0.0213836462926,
#   'current_price_btc': 2.9627796652862273e-06,
#   'max_price_usd_days_after_launch': 0,
#   'max_price_btc_days_after_launch': 0},
#  'ROOBEE': {'id': 4804,
#   'name': 'ROOBEE',
#   'date_added': datetime.date(2019, 10, 17),
#   'date_start': datetime.date(2019, 12, 2),
#   'starting_price_usd': 0.00368334581388,
#   'starting_price_btc': 5.030526896966803e-07,
#   'max_price_usd': 0.0043253622672,
#   'max_price_btc': 5.807174656924205e-07,
#   'max_price_usd_date': datetime.date(2019, 12, 5),
#   'max_price_btc_date': datetime.date(2019, 12, 5),
#   'current_price_usd': 0.00366507410401,
#   'current_price_btc': 5.078089526240319e-07,
#   'max_price_usd_days_after_launch': 49,
#   'max_price_btc_days_after_launch': 49},
#  'NWC': {'id': 4890,
#   'name': 'Newscrypto',
#   'date_added': datetime.date(2019, 11, 6),
#   'date_start': datetime.date(2019, 12, 2),
#   'starting_price_usd': 0.0237146401322,
#   'starting_price_btc': 3.238825270963468e-06,
#   'max_price_usd': 0.024890407927,
#   'max_price_btc': 3.448653866497725e-06,
#   'max_price_usd_date': datetime.date(2019, 12, 11),
#   'max_price_btc_date': datetime.date(2019, 12, 11),
#   'current_price_usd': 0.024890407927,
#   'current_price_btc': 3.448653866497725e-06,
#   'max_price_usd_days_after_launch': 35,
#   'max_price_btc_days_after_launch': 35},
#  'VANTA': {'id': 3824,
#   'name': 'Vanta Network',
#   'date_added': datetime.date(2019, 3, 27),
#   'date_start': datetime.date(2019, 12, 2),
#   'starting_price_usd': 0.0007008014998,
#   'starting_price_btc': 9.571191444728762e-08,
#   'max_price_usd': 0.000783866144186,
#   'max_price_btc': 1.0362643459596589e-07,
#   'max_price_usd_date': datetime.date(2019, 12, 8),
#   'max_price_btc_date': datetime.date(2019, 12, 8),
#   'current_price_usd': 0.000723275439952,
#   'current_price_btc': 1.002123649338657e-07,
#   'max_price_usd_days_after_launch': 256,
#   'max_price_btc_days_after_launch': 256},
#  'TN': {'id': 4782,
#   'name': 'TurtleNetwork',
#   'date_added': datetime.date(2019, 11, 11),
#   'date_start': datetime.date(2019, 12, 2),
#   'starting_price_usd': 0.0061922529641,
#   'starting_price_btc': 8.457065033465877e-07,
#   'max_price_usd': 0.00663677363508,
#   'max_price_btc': 8.96752315637789e-07,
#   'max_price_usd_date': datetime.date(2019, 12, 9),
#   'max_price_btc_date': datetime.date(2019, 12, 9),
#   'current_price_usd': 0.005756244448,
#   'current_price_btc': 7.975479843609741e-07,
#   'max_price_usd_days_after_launch': 28,
#   'max_price_btc_days_after_launch': 28},
#  '999': {'id': 4949,
#   'name': '999',
#   'date_added': datetime.date(2019, 11, 20),
#   'date_start': datetime.date(2019, 12, 3),
#   'starting_price_usd': 0.512242122781,
#   'starting_price_btc': 6.99770414388996e-05,
#   'max_price_usd': 3.0127434234,
#   'max_price_btc': 0.0004023495774333418,
#   'max_price_usd_date': datetime.date(2019, 12, 8),
#   'max_price_btc_date': datetime.date(2019, 12, 10),
#   'current_price_usd': 2.87358185696,
#   'current_price_btc': 0.0003981449083023225,
#   'max_price_usd_days_after_launch': 18,
#   'max_price_btc_days_after_launch': 20},
#  'JUL': {'id': 4967,
#   'name': 'Joule',
#   'date_added': datetime.date(2019, 11, 26),
#   'date_start': datetime.date(2019, 12, 3),
#   'starting_price_usd': 0.0380524957507,
#   'starting_price_btc': 5.198325076320829e-06,
#   'max_price_usd': 0.0380544325786,
#   'max_price_btc': 5.223645406569823e-06,
#   'max_price_usd_date': datetime.date(2019, 12, 5),
#   'max_price_btc_date': datetime.date(2019, 12, 10),
#   'current_price_usd': 0.0375839369839,
#   'current_price_btc': 5.207387117875803e-06,
#   'max_price_usd_days_after_launch': 9,
#   'max_price_btc_days_after_launch': 14},
#  'VLX': {'id': 4747,
#   'name': 'Velas',
#   'date_added': datetime.date(2019, 10, 3),
#   'date_start': datetime.date(2019, 12, 3),
#   'starting_price_usd': 0.0240061685571,
#   'starting_price_btc': 3.279466051696804e-06,
#   'max_price_usd': 0.0246595983237,
#   'max_price_btc': 3.3851488943415424e-06,
#   'max_price_usd_date': datetime.date(2019, 12, 5),
#   'max_price_btc_date': datetime.date(2019, 12, 4),
#   'current_price_usd': 0.02284317468,
#   'current_price_btc': 3.1650024746203484e-06,
#   'max_price_usd_days_after_launch': 63,
#   'max_price_btc_days_after_launch': 62},
#  'LINKA': {'id': 4850,
#   'name': 'LINKA',
#   'date_added': datetime.date(2019, 11, 1),
#   'date_start': datetime.date(2019, 12, 3),
#   'starting_price_usd': 0.00864890094102,
#   'starting_price_btc': 1.181520364363802e-06,
#   'max_price_usd': 0.00864890094102,
#   'max_price_btc': 1.1895494514782747e-06,
#   'max_price_usd_date': datetime.date(2019, 12, 3),
#   'max_price_btc_date': datetime.date(2019, 12, 4),
#   'current_price_usd': 0.00678554646941,
#   'current_price_btc': 9.401614122461378e-07,
#   'max_price_usd_days_after_launch': 0,
#   'max_price_btc_days_after_launch': 33},
#  'CUT': {'id': 4752,
#   'name': 'CUTcoin',
#   'date_added': datetime.date(2019, 11, 19),
#   'date_start': datetime.date(2019, 12, 3),
#   'starting_price_usd': 0.0571611477066,
#   'starting_price_btc': 7.80874477882391e-06,
#   'max_price_usd': 0.0589084061034,
#   'max_price_btc': 8.161967576969096e-06,
#   'max_price_usd_date': datetime.date(2019, 12, 11),
#   'max_price_btc_date': datetime.date(2019, 12, 11),
#   'current_price_usd': 0.0589084061034,
#   'current_price_btc': 8.161967576969096e-06,
#   'max_price_usd_days_after_launch': 22,
#   'max_price_btc_days_after_launch': 22},
#  'GDC': {'id': 4678,
#   'name': 'Global Digital Content',
#   'date_added': datetime.date(2019, 9, 25),
#   'date_start': datetime.date(2019, 12, 3),
#   'starting_price_usd': 0.00141538317664,
#   'starting_price_btc': 1.9335451498197716e-07,
#   'max_price_usd': 0.00141538317664,
#   'max_price_btc': 1.9335451498197716e-07,
#   'max_price_usd_date': datetime.date(2019, 12, 3),
#   'max_price_btc_date': datetime.date(2019, 12, 3),
#   'current_price_usd': 0.00103097325562,
#   'current_price_btc': 1.4284498328341357e-07,
#   'max_price_usd_days_after_launch': 0,
#   'max_price_btc_days_after_launch': 0},
#  'TRB': {'id': 4944,
#   'name': 'Tellor',
#   'date_added': datetime.date(2019, 11, 19),
#   'date_start': datetime.date(2019, 12, 3),
#   'starting_price_usd': 2.1253201477,
#   'starting_price_btc': 0.0002903385126531566,
#   'max_price_usd': 7.21733062746,
#   'max_price_btc': 0.0009999866312830792,
#   'max_price_usd_date': datetime.date(2019, 12, 11),
#   'max_price_btc_date': datetime.date(2019, 12, 11),
#   'current_price_usd': 7.21733062746,
#   'current_price_btc': 0.0009999866312830792,
#   'max_price_usd_days_after_launch': 22,
#   'max_price_btc_days_after_launch': 22},
#  'MERI': {'id': 3915,
#   'name': 'Merebel',
#   'date_added': datetime.date(2019, 5, 8),
#   'date_start': datetime.date(2019, 12, 4),
#   'starting_price_usd': 0.141059673877,
#   'starting_price_btc': 1.945104814392474e-05,
#   'max_price_usd': 0.161386140121,
#   'max_price_btc': 2.2174152793048055e-05,
#   'max_price_usd_date': datetime.date(2019, 12, 10),
#   'max_price_btc_date': datetime.date(2019, 12, 10),
#   'current_price_usd': 0.12673648622,
#   'current_price_btc': 1.7559787469566713e-05,
#   'max_price_usd_days_after_launch': 216,
#   'max_price_btc_days_after_launch': 216},
#  'TOSC': {'id': 3707,
#   'name': 'T.OS',
#   'date_added': datetime.date(2019, 1, 18),
#   'date_start': datetime.date(2019, 12, 5),
#   'starting_price_usd': 0.00767512895968,
#   'starting_price_btc': 1.0304527489238817e-06,
#   'max_price_usd': 0.00884600805047,
#   'max_price_btc': 1.1694347070306717e-06,
#   'max_price_usd_date': datetime.date(2019, 12, 8),
#   'max_price_btc_date': datetime.date(2019, 12, 8),
#   'current_price_usd': 0.00836999341119,
#   'current_price_btc': 1.1596921281771837e-06,
#   'max_price_usd_days_after_launch': 324,
#   'max_price_btc_days_after_launch': 324},
#  'AIDUS': {'id': 3785,
#   'name': 'AIDUS TOKEN',
#   'date_added': datetime.date(2019, 3, 7),
#   'date_start': datetime.date(2019, 12, 5),
#   'starting_price_usd': 0.002045265157,
#   'starting_price_btc': 2.7459461780779705e-07,
#   'max_price_usd': 0.00238574957217,
#   'max_price_btc': 3.161190693101471e-07,
#   'max_price_usd_date': datetime.date(2019, 12, 6),
#   'max_price_btc_date': datetime.date(2019, 12, 6),
#   'current_price_usd': 0.00168397087978,
#   'current_price_btc': 2.333201088007573e-07,
#   'max_price_usd_days_after_launch': 274,
#   'max_price_btc_days_after_launch': 274},
#  'NBX': {'id': 4297,
#   'name': 'Netbox Coin',
#   'date_added': datetime.date(2019, 9, 9),
#   'date_start': datetime.date(2019, 12, 6),
#   'starting_price_usd': 0.0628981687955,
#   'starting_price_btc': 8.33419853151678e-06,
#   'max_price_usd': 0.0628981687955,
#   'max_price_btc': 8.33419853151678e-06,
#   'max_price_usd_date': datetime.date(2019, 12, 6),
#   'max_price_btc_date': datetime.date(2019, 12, 6),
#   'current_price_usd': 0.047018358845,
#   'current_price_btc': 6.215786871010607e-06,
#   'max_price_usd_days_after_launch': 0,
#   'max_price_btc_days_after_launch': 0},
#  'BTZC': {'id': 4867,
#   'name': 'BeatzCoin',
#   'date_added': datetime.date(2019, 11, 5),
#   'date_start': datetime.date(2019, 12, 9),
#   'starting_price_usd': 0.000788936285126,
#   'starting_price_btc': 1.0660005591239175e-07,
#   'max_price_usd': 0.000788936285126,
#   'max_price_btc': 1.0660005591239175e-07,
#   'max_price_usd_date': datetime.date(2019, 12, 9),
#   'max_price_btc_date': datetime.date(2019, 12, 9),
#   'current_price_usd': 0.0007392115667,
#   'current_price_btc': 1.0242037153977078e-07,
#   'max_price_usd_days_after_launch': 0,
#   'max_price_btc_days_after_launch': 0},
#  'VNDC': {'id': 4805,
#   'name': 'VNDC',
#   'date_added': datetime.date(2019, 11, 7),
#   'date_start': datetime.date(2019, 12, 11),
#   'starting_price_usd': 4.37948578365e-05,
#   'starting_price_btc': 6.067932122829122e-09,
#   'max_price_usd': 4.37948578365e-05,
#   'max_price_btc': 6.067932122829122e-09,
#   'max_price_usd_date': datetime.date(2019, 12, 11),
#   'max_price_btc_date': datetime.date(2019, 12, 11),
#   'current_price_usd': 4.37948578365e-05,
#   'current_price_btc': 6.067932122829122e-09,
#   'max_price_usd_days_after_launch': 0,
#   'max_price_btc_days_after_launch': 0}}

# %% [markdown]
# # Analisi risultati della strategia

# %%
## Calcolo dati di riepilogo

# Numero di coin su cui ho investito
strategy['number_of_coins'] = len(strategy['coins'])
# Importo totale dell'investimento in USD
strategy['total_invested_amount_usd'] = strategy['number_of_coins'] * strategy['invested_amount_usd']
# Aggregato di profitti e perdite in USD
strategy['profit_and_loss_usd'] = 0
# Aggregato di profitti e perdite in BTC
strategy['profit_and_loss_btc'] = 0
# Analizzo risultati per singola coin
for (symbol, coin) in strategy['coins'].items():
    # Valore corrente in USD dell'investimento
    coin['current_usd_value'] = coins[symbol]['current_price_usd'] * coin['investment_coins_amount']
    # Profitti e perdite in USD
    coin['profit_and_loss_usd'] = coin['current_usd_value'] - coin['investment_amount_usd'] 
    # Profitti e perdite in USD (percentuale)
    coin['profit_and_loss_usd_perc'] = coin['profit_and_loss_usd'] * 100 / coin['investment_amount_usd'] 
    # Valore corrente in BTC dell'investimento
    coin['current_btc_value'] = coins[symbol]['current_price_btc'] * coin['investment_coins_amount']
    # Profitti e perdite in BTC
    coin['profit_and_loss_btc'] = coin['current_btc_value'] - coin['investment_amount_btc'] 
    # Profitti e perdite in BTC (percentuale)
    coin['profit_and_loss_btc_perc'] = coin['profit_and_loss_btc'] * 100 / coin['investment_amount_btc'] 
    strategy['profit_and_loss_usd'] += coin['profit_and_loss_usd']
    strategy['profit_and_loss_btc'] += coin['profit_and_loss_btc']
    
strategy
# Out:
# {'waiting_time': datetime.timedelta(days=91),
#  'invested_amount_usd': 100,
#  'invest_only_on_new_max': False,
#  'coins': {'AGVC': {'investment_start_date': datetime.date(2019, 4, 12),
#    'investment_buy_usd_price': 0.0200448053862,
#    'investment_buy_btc_price': 3.938432485288486e-06,
#    'investment_coins_amount': 4988.823691391175,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.019648145289551826,
#    'current_usd_value': 258.45509409269096,
#    'profit_and_loss_usd': 158.45509409269096,
#    'current_btc_value': 0.03580986547801515,
#    'profit_and_loss_btc': 0.016161720188463326,
#    'profit_and_loss_usd_perc': 158.45509409269096,
#    'profit_and_loss_btc_perc': 82.25570378420169},
#   'ULT': {'investment_start_date': datetime.date(2019, 4, 12),
#    'investment_buy_usd_price': 0.0071165333506,
#    'investment_buy_btc_price': 1.3982668123052985e-06,
#    'investment_coins_amount': 14051.785479452426,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.019648145289551822,
#    'current_usd_value': 335.56276935717057,
#    'profit_and_loss_usd': 235.56276935717057,
#    'current_btc_value': 0.04649340602975689,
#    'profit_and_loss_btc': 0.02684526074020507,
#    'profit_and_loss_usd_perc': 235.5627693571706,
#    'profit_and_loss_btc_perc': 136.6299991403281},
#   'XFC': {'investment_start_date': datetime.date(2019, 4, 12),
#    'investment_buy_usd_price': 0.00507931010291,
#    'investment_buy_btc_price': 9.979902287266411e-07,
#    'investment_coins_amount': 19687.71308975775,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.019648145289551826,
#    'current_usd_value': 52.844611623382114,
#    'profit_and_loss_usd': -47.155388376617886,
#    'current_btc_value': 0.007321807450204885,
#    'profit_and_loss_btc': -0.01232633783934694,
#    'profit_and_loss_usd_perc': -47.155388376617886,
#    'profit_and_loss_btc_perc': -62.73537607593752},
#   'FTN': {'investment_start_date': datetime.date(2019, 4, 12),
#    'investment_buy_usd_price': 0.0441804108759,
#    'investment_buy_btc_price': 8.680631318417789e-06,
#    'investment_coins_amount': 2263.4465822622997,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.019648145289551826,
#    'current_usd_value': 30.990525788135475,
#    'profit_and_loss_usd': -69.00947421186453,
#    'current_btc_value': 0.004293846725915528,
#    'profit_and_loss_btc': -0.015354298563636298,
#    'profit_and_loss_usd_perc': -69.00947421186453,
#    'profit_and_loss_btc_perc': -78.14630000624618},
#   'B2G': {'investment_start_date': datetime.date(2019, 4, 16),
#    'investment_buy_usd_price': 0.267341980661,
#    'investment_buy_btc_price': 5.106273451780195e-05,
#    'investment_coins_amount': 374.05273856635284,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.019100155685070452,
#    'current_usd_value': 2.0378737660167157,
#    'profit_and_loss_usd': -97.96212623398328,
#    'current_btc_value': 0.0001969757506917697,
#    'profit_and_loss_btc': -0.01890317993437868,
#    'profit_and_loss_usd_perc': -97.96212623398328,
#    'profit_and_loss_btc_perc': -98.9687217531649},
#   'MCW': {'investment_start_date': datetime.date(2019, 4, 22),
#    'investment_buy_usd_price': 0.263212040908,
#    'investment_buy_btc_price': 4.874869932235473e-05,
#    'investment_coins_amount': 379.9218290129547,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.018520695008551594,
#    'current_usd_value': 91.87384757923137,
#    'profit_and_loss_usd': -8.126152420768634,
#    'current_btc_value': 0.011278597480439613,
#    'profit_and_loss_btc': -0.007242097528111981,
#    'profit_and_loss_usd_perc': -8.126152420768634,
#    'profit_and_loss_btc_perc': -39.10273088978612},
#   'CVNT': {'investment_start_date': datetime.date(2019, 4, 30),
#    'investment_buy_usd_price': 0.015708595193,
#    'investment_buy_btc_price': 2.9357872460103063e-06,
#    'investment_coins_amount': 6365.9416244020085,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.018689050229765546,
#    'current_usd_value': 39.07365847606256,
#    'profit_and_loss_usd': -60.92634152393744,
#    'current_btc_value': 0.005413793288438327,
#    'profit_and_loss_btc': -0.013275256941327218,
#    'profit_and_loss_usd_perc': -60.92634152393744,
#    'profit_and_loss_btc_perc': -71.03227172124603},
#   'WIB': {'investment_start_date': datetime.date(2019, 5, 7),
#    'investment_buy_usd_price': 0.00134132420607,
#    'investment_buy_btc_price': 2.30092436261333e-07,
#    'investment_coins_amount': 74553.19120273991,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.017154125394895404,
#    'current_usd_value': 11.245672517157873,
#    'profit_and_loss_usd': -88.75432748284213,
#    'current_btc_value': 0.001573672236087014,
#    'profit_and_loss_btc': -0.01558045315880839,
#    'profit_and_loss_usd_perc': -88.75432748284213,
#    'profit_and_loss_btc_perc': -90.826275313603},
#   'LAMB': {'investment_start_date': datetime.date(2019, 5, 8),
#    'investment_buy_usd_price': 0.0601802127467,
#    'investment_buy_btc_price': 1.0059447063122546e-05,
#    'investment_coins_amount': 1661.6757474903334,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.016715539217953598,
#    'current_usd_value': 50.99448233586184,
#    'profit_and_loss_usd': -49.00551766413816,
#    'current_btc_value': 0.007065465507572187,
#    'profit_and_loss_btc': -0.00965007371038141,
#    'profit_and_loss_usd_perc': -49.00551766413816,
#    'profit_and_loss_btc_perc': -57.731154134810026},
#   'HYN': {'investment_start_date': datetime.date(2019, 5, 8),
#    'investment_buy_usd_price': 0.0536042718847,
#    'investment_buy_btc_price': 8.960243089385502e-06,
#    'investment_coins_amount': 1865.5229608396658,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.016715539217953594,
#    'current_usd_value': 134.3846884075686,
#    'profit_and_loss_usd': 34.3846884075686,
#    'current_btc_value': 0.01861947287622103,
#    'profit_and_loss_btc': 0.001903933658267437,
#    'profit_and_loss_usd_perc': 34.3846884075686,
#    'profit_and_loss_btc_perc': 11.390201856141658},
#   'FIII': {'investment_start_date': datetime.date(2019, 5, 8),
#    'investment_buy_usd_price': 0.0266208644149,
#    'investment_buy_btc_price': 4.449821031430862e-06,
#    'investment_coins_amount': 3756.4520235499513,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.016715539217953594,
#    'current_usd_value': 3.9494487009652923,
#    'profit_and_loss_usd': -96.05055129903471,
#    'current_btc_value': 0.0005393956723674542,
#    'profit_and_loss_btc': -0.01617614354558614,
#    'profit_and_loss_usd_perc': -96.05055129903471,
#    'profit_and_loss_btc_perc': -96.77308840992633},
#   'SDA': {'investment_start_date': datetime.date(2019, 5, 8),
#    'investment_buy_usd_price': 0.00721572713277,
#    'investment_buy_btc_price': 1.2061476987386877e-06,
#    'investment_coins_amount': 13858.61717883609,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.016715539217953594,
#    'current_usd_value': 16.125887405657938,
#    'profit_and_loss_usd': -83.87411259434207,
#    'current_btc_value': 0.0022342986147648927,
#    'profit_and_loss_btc': -0.014481240603188702,
#    'profit_and_loss_usd_perc': -83.87411259434207,
#    'profit_and_loss_btc_perc': -86.6334038906438},
#   'BEAM': {'investment_start_date': datetime.date(2019, 5, 8),
#    'investment_buy_usd_price': 0.482107587614,
#    'investment_buy_btc_price': 8.058688288034815e-05,
#    'investment_coins_amount': 207.42258070425788,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.016715539217953594,
#    'current_usd_value': 112.7537149430283,
#    'profit_and_loss_usd': 12.7537149430283,
#    'current_btc_value': 0.015622425158345893,
#    'profit_and_loss_btc': -0.0010931140596077017,
#    'profit_and_loss_usd_perc': 12.7537149430283,
#    'profit_and_loss_btc_perc': -6.539508210621317},
#   'CAJ': {'investment_start_date': datetime.date(2019, 5, 8),
#    'investment_buy_usd_price': 7.54402561843,
#    'investment_buy_btc_price': 0.0012610245608611328,
#    'investment_coins_amount': 13.255522324274818,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.016715539217953594,
#    'current_usd_value': 27.51728004606142,
#    'profit_and_loss_usd': -72.48271995393858,
#    'current_btc_value': 0.0038126162698767893,
#    'profit_and_loss_btc': -0.012902922948076805,
#    'profit_and_loss_usd_perc': -72.48271995393858,
#    'profit_and_loss_btc_perc': -77.19118587702042},
#   'ADM': {'investment_start_date': datetime.date(2019, 5, 8),
#    'investment_buy_usd_price': 0.0284458347054,
#    'investment_buy_btc_price': 4.754874656055391e-06,
#    'investment_coins_amount': 3515.4531774388943,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.016715539217953594,
#    'current_usd_value': 38.791222095884834,
#    'profit_and_loss_usd': -61.208777904115166,
#    'current_btc_value': 0.005299241970441828,
#    'profit_and_loss_btc': -0.011416297247511767,
#    'profit_and_loss_usd_perc': -61.208777904115166,
#    'profit_and_loss_btc_perc': -68.29751106832323},
#   'CTX': {'investment_start_date': datetime.date(2019, 5, 9),
#    'investment_buy_usd_price': 0.0124632697582,
#    'investment_buy_btc_price': 2.0184973439167772e-06,
#    'investment_coins_amount': 8023.576632785845,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.016195568121990946,
#    'current_usd_value': 63.2280804493965,
#    'profit_and_loss_usd': -36.7719195506035,
#    'current_btc_value': 0.006818130376342933,
#    'profit_and_loss_btc': -0.009377437745648013,
#    'profit_and_loss_usd_perc': -36.7719195506035,
#    'profit_and_loss_btc_perc': -57.90125838756455},
#   'DASHG': {'investment_start_date': datetime.date(2019, 5, 9),
#    'investment_buy_usd_price': 0.250125725237,
#    'investment_buy_btc_price': 4.050928222138223e-05,
#    'investment_coins_amount': 399.79894073369564,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.016195568121990946,
#    'current_usd_value': 65.25772337385096,
#    'profit_and_loss_usd': -34.742276626149035,
#    'current_btc_value': 0.005698943036124955,
#    'profit_and_loss_btc': -0.01049662508586599,
#    'profit_and_loss_usd_perc': -34.742276626149035,
#    'profit_and_loss_btc_perc': -64.81171272783746},
#   'CLB': {'investment_start_date': datetime.date(2019, 5, 10),
#    'investment_buy_usd_price': 0.00550098306979,
#    'investment_buy_btc_price': 8.623786348400092e-07,
#    'investment_coins_amount': 18178.568945099025,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.015676809470219485,
#    'current_usd_value': 22.291616969961193,
#    'profit_and_loss_usd': -77.7083830300388,
#    'current_btc_value': 0.003088582207226554,
#    'profit_and_loss_btc': -0.01258822726299293,
#    'profit_and_loss_usd_perc': -77.7083830300388,
#    'profit_and_loss_btc_perc': -80.29840055724482},
#   'S4F': {'investment_start_date': datetime.date(2019, 5, 14),
#    'investment_buy_usd_price': 0.0970009201489,
#    'investment_buy_btc_price': 1.213358402317044e-05,
#    'investment_coins_amount': 1030.918055689537,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.012508730849712497,
#    'current_usd_value': 33.96011557862894,
#    'profit_and_loss_usd': -66.03988442137106,
#    'current_btc_value': 0.004705293872259336,
#    'profit_and_loss_btc': -0.007803436977453161,
#    'profit_and_loss_usd_perc': -66.03988442137106,
#    'profit_and_loss_btc_perc': -62.383922647376465},
#   'SPND': {'investment_start_date': datetime.date(2019, 5, 14),
#    'investment_buy_usd_price': 0.0396841246303,
#    'investment_buy_btc_price': 4.963980340068692e-06,
#    'investment_coins_amount': 2519.8993534973188,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.0125087308497125,
#    'current_usd_value': 3.828960102674975,
#    'profit_and_loss_usd': -96.17103989732503,
#    'current_btc_value': 0.0005305159361583483,
#    'profit_and_loss_btc': -0.011978214913554152,
#    'profit_and_loss_usd_perc': -96.17103989732503,
#    'profit_and_loss_btc_perc': -95.75883482879048},
#   'LTO': {'investment_start_date': datetime.date(2019, 5, 14),
#    'investment_buy_usd_price': 0.0709897390308,
#    'investment_buy_btc_price': 8.879915386276074e-06,
#    'investment_coins_amount': 1408.654283918602,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.0125087308497125,
#    'current_usd_value': 34.314301410280144,
#    'profit_and_loss_usd': -65.68569858971986,
#    'current_btc_value': 0.004754367569298173,
#    'profit_and_loss_btc': -0.0077543632804143265,
#    'profit_and_loss_usd_perc': -65.68569858971986,
#    'profit_and_loss_btc_perc': -61.99160709091885},
#   'WCO': {'investment_start_date': datetime.date(2019, 5, 14),
#    'investment_buy_usd_price': 0.00211284700163,
#    'investment_buy_btc_price': 2.642903447001174e-07,
#    'investment_coins_amount': 47329.50370890694,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.0125087308497125,
#    'current_usd_value': 137.58804946204407,
#    'profit_and_loss_usd': 37.58804946204407,
#    'current_btc_value': 0.018435762147386865,
#    'profit_and_loss_btc': 0.005927031297674365,
#    'profit_and_loss_usd_perc': 37.58804946204407,
#    'profit_and_loss_btc_perc': 47.383154765142244},
#   'GRIN': {'investment_start_date': datetime.date(2019, 5, 16),
#    'investment_buy_usd_price': 2.15090156447,
#    'investment_buy_btc_price': 0.00027278710319996336,
#    'investment_coins_amount': 46.4921322536863,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.01268245407907267,
#    'current_usd_value': 54.21874739708786,
#    'profit_and_loss_usd': -45.78125260291214,
#    'current_btc_value': 0.007512198811526955,
#    'profit_and_loss_btc': -0.005170255267545714,
#    'profit_and_loss_usd_perc': -45.78125260291213,
#    'profit_and_loss_btc_perc': -40.76699379560269},
#   'AEN': {'investment_start_date': datetime.date(2019, 5, 16),
#    'investment_buy_usd_price': 0.0273367184212,
#    'investment_buy_btc_price': 3.4669667604940897e-06,
#    'investment_coins_amount': 3658.0835511861815,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.01268245407907267,
#    'current_usd_value': 92.4146342375466,
#    'profit_and_loss_usd': -7.5853657624534065,
#    'current_btc_value': 0.012804373741844944,
#    'profit_and_loss_btc': 0.00012191966277227441,
#    'profit_and_loss_usd_perc': -7.585365762453407,
#    'profit_and_loss_btc_perc': 0.9613254817413782},
#   'USDS': {'investment_start_date': datetime.date(2019, 5, 16),
#    'investment_buy_usd_price': 0.996126002656,
#    'investment_buy_btc_price': 0.00012633322285654942,
#    'investment_coins_amount': 100.3889063565925,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.01268245407907267,
#    'current_usd_value': 101.10908186560162,
#    'profit_and_loss_usd': 1.109081865601624,
#    'current_btc_value': 0.014009020146897571,
#    'profit_and_loss_btc': 0.0013265660678249015,
#    'profit_and_loss_usd_perc': 1.109081865601624,
#    'profit_and_loss_btc_perc': 10.459853113238308},
#   'CCX': {'investment_start_date': datetime.date(2019, 5, 18),
#    'investment_buy_usd_price': 0.164217488188,
#    'investment_buy_btc_price': 2.2584622851432254e-05,
#    'investment_coins_amount': 608.948541981824,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.013752873156589056,
#    'current_usd_value': 59.918119033189654,
#    'profit_and_loss_usd': -40.081880966810346,
#    'current_btc_value': 0.008301866867072516,
#    'profit_and_loss_btc': -0.0054510062895165405,
#    'profit_and_loss_usd_perc': -40.081880966810346,
#    'profit_and_loss_btc_perc': -39.63540001752246},
#   'HALO': {'investment_start_date': datetime.date(2019, 5, 20),
#    'investment_buy_usd_price': 0.000350107392388,
#    'investment_buy_btc_price': 4.388240530783636e-08,
#    'investment_coins_amount': 285626.6453499412,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.012533984217963754,
#    'current_usd_value': 122.18607184504062,
#    'profit_and_loss_usd': 22.186071845040615,
#    'current_btc_value': 0.016929311497682474,
#    'profit_and_loss_btc': 0.00439532727971872,
#    'profit_and_loss_usd_perc': 22.186071845040615,
#    'profit_and_loss_btc_perc': 35.06727951212289},
#   'SOLVE': {'investment_start_date': datetime.date(2019, 5, 22),
#    'investment_buy_usd_price': 0.306315372484,
#    'investment_buy_btc_price': 3.98844685334042e-05,
#    'investment_coins_amount': 326.4609255130458,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.013020720511011087,
#    'current_usd_value': 34.56236265861257,
#    'profit_and_loss_usd': -65.43763734138743,
#    'current_btc_value': 0.0047887373307620605,
#    'profit_and_loss_btc': -0.008231983180249026,
#    'profit_and_loss_usd_perc': -65.43763734138743,
#    'profit_and_loss_btc_perc': -63.22217862895972},
#   'HEDG': {'investment_start_date': datetime.date(2019, 5, 22),
#    'investment_buy_usd_price': 0.0754752213267,
#    'investment_buy_btc_price': 9.827417624016641e-06,
#    'investment_coins_amount': 1324.938148470512,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.013020720511011089,
#    'current_usd_value': 1598.6820304469275,
#    'profit_and_loss_usd': 1498.6820304469275,
#    'current_btc_value': 0.22150303770717425,
#    'profit_and_loss_btc': 0.20848231719616317,
#    'profit_and_loss_usd_perc': 1498.6820304469275,
#    'profit_and_loss_btc_perc': 1601.15806970788},
#   'BTU': {'investment_start_date': datetime.date(2019, 5, 22),
#    'investment_buy_usd_price': 0.219475197392,
#    'investment_buy_btc_price': 2.8577252043402216e-05,
#    'investment_coins_amount': 455.6323502076279,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.013020720511011087,
#    'current_usd_value': 59.56466060285916,
#    'profit_and_loss_usd': -40.43533939714084,
#    'current_btc_value': 0.008252893954053956,
#    'profit_and_loss_btc': -0.004767826556957131,
#    'profit_and_loss_usd_perc': -40.43533939714084,
#    'profit_and_loss_btc_perc': -36.61722523669236},
#   'PLA': {'investment_start_date': datetime.date(2019, 5, 22),
#    'investment_buy_usd_price': 0.00102384544758,
#    'investment_buy_btc_price': 1.3331205419410232e-07,
#    'investment_coins_amount': 97670.99149228411,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.013020720511011085,
#    'current_usd_value': 3.8453344524075477,
#    'profit_and_loss_usd': -96.15466554759246,
#    'current_btc_value': 0.0005327846601054303,
#    'profit_and_loss_btc': -0.012487935850905655,
#    'profit_and_loss_usd_perc': -96.15466554759244,
#    'profit_and_loss_btc_perc': -95.90817835576091},
#   'VEO': {'investment_start_date': datetime.date(2019, 5, 22),
#    'investment_buy_usd_price': 85.713259266,
#    'investment_buy_btc_price': 0.011160483929904173,
#    'investment_coins_amount': 1.1666806379356425,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.013020720511011087,
#    'current_usd_value': 45.589321646762265,
#    'profit_and_loss_usd': -54.410678353237735,
#    'current_btc_value': 0.0061207625382283925,
#    'profit_and_loss_btc': -0.006899957972782695,
#    'profit_and_loss_usd_perc': -54.410678353237735,
#    'profit_and_loss_btc_perc': -52.992136394815354},
#   'KT': {'investment_start_date': datetime.date(2019, 5, 24),
#    'investment_buy_usd_price': 0.144347383233,
#    'investment_buy_btc_price': 1.8071950458711417e-05,
#    'investment_coins_amount': 692.7732097407255,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.012519763125556886,
#    'current_usd_value': 96.0977862238709,
#    'profit_and_loss_usd': -3.902213776129102,
#    'current_btc_value': 0.013314687448867706,
#    'profit_and_loss_btc': 0.0007949243233108198,
#    'profit_and_loss_usd_perc': -3.902213776129102,
#    'profit_and_loss_btc_perc': 6.349355936999495},
#   'EVY': {'investment_start_date': datetime.date(2019, 5, 28),
#    'investment_buy_usd_price': 0.000440428692174,
#    'investment_buy_btc_price': 5.050809917497766e-08,
#    'investment_coins_amount': 227051.51089587287,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.011467940230157268,
#    'current_usd_value': 51.44138540603799,
#    'profit_and_loss_usd': -48.55861459396201,
#    'current_btc_value': 0.0071273855052449,
#    'profit_and_loss_btc': -0.004340554724912368,
#    'profit_and_loss_usd_perc': -48.55861459396201,
#    'profit_and_loss_btc_perc': -37.849471115117964},
#   'VGW': {'investment_start_date': datetime.date(2019, 5, 28),
#    'investment_buy_usd_price': 0.201391789882,
#    'investment_buy_btc_price': 2.309549009211167e-05,
#    'investment_coins_amount': 496.5445714474868,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.011467940230157268,
#    'current_usd_value': 40.059150518434635,
#    'profit_and_loss_usd': -59.940849481565365,
#    'current_btc_value': 0.005504052105648537,
#    'profit_and_loss_btc': -0.00596388812450873,
#    'profit_and_loss_usd_perc': -59.940849481565365,
#    'profit_and_loss_btc_perc': -52.00487624469371},
#   'PLTC': {'investment_start_date': datetime.date(2019, 5, 28),
#    'investment_buy_usd_price': 0.26437520313,
#    'investment_buy_btc_price': 3.0318390278305265e-05,
#    'investment_coins_amount': 378.25030039155166,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.011467940230157268,
#    'current_usd_value': 107.71441164584986,
#    'profit_and_loss_usd': 7.714411645849864,
#    'current_btc_value': 0.01492421190080352,
#    'profit_and_loss_btc': 0.0034562716706462524,
#    'profit_and_loss_usd_perc': 7.7144116458498635,
#    'profit_and_loss_btc_perc': 30.138556717947374},
#   'MPG': {'investment_start_date': datetime.date(2019, 5, 29),
#    'investment_buy_usd_price': 0.0128820421704,
#    'investment_buy_btc_price': 1.487621731633293e-06,
#    'investment_coins_amount': 7762.744344198565,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.011548027183543221,
#    'current_usd_value': 25.692138929686735,
#    'profit_and_loss_usd': -74.30786107031327,
#    'current_btc_value': 0.0035597365265495704,
#    'profit_and_loss_btc': -0.00798829065699365,
#    'profit_and_loss_usd_perc': -74.30786107031327,
#    'profit_and_loss_btc_perc': -69.17450513432759},
#   'XPC': {'investment_start_date': datetime.date(2019, 5, 30),
#    'investment_buy_usd_price': 1.6746731542e-05,
#    'investment_buy_btc_price': 2.0129560002213283e-09,
#    'investment_coins_amount': 5971314.447192564,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.012019993245684575,
#    'current_usd_value': 47.718206999965055,
#    'profit_and_loss_usd': -52.281793000034945,
#    'current_btc_value': 0.00661152599649671,
#    'profit_and_loss_btc': -0.005408467249187865,
#    'profit_and_loss_usd_perc': -52.28179300003494,
#    'profit_and_loss_btc_perc': -44.9955930809663},
#   'SWC': {'investment_start_date': datetime.date(2019, 5, 30),
#    'investment_buy_usd_price': 0.00240948135119,
#    'investment_buy_btc_price': 2.8961949566906745e-07,
#    'investment_coins_amount': 41502.70760577241,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.012019993245684576,
#    'current_usd_value': 34.05463744796156,
#    'profit_and_loss_usd': -65.94536255203843,
#    'current_btc_value': 0.003381659531044371,
#    'profit_and_loss_btc': -0.008638333714640206,
#    'profit_and_loss_usd_perc': -65.94536255203843,
#    'profit_and_loss_btc_perc': -71.86637744361083},
#   'GMB': {'investment_start_date': datetime.date(2019, 5, 31),
#    'investment_buy_usd_price': 0.00358554560724,
#    'investment_buy_btc_price': 4.18163731722985e-07,
#    'investment_coins_amount': 27889.758199722284,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.011662485365647589,
#    'current_usd_value': 4.726796495260859,
#    'profit_and_loss_usd': -95.27320350473914,
#    'current_btc_value': 0.0006549143371751079,
#    'profit_and_loss_btc': -0.01100757102847248,
#    'profit_and_loss_usd_perc': -95.27320350473914,
#    'profit_and_loss_btc_perc': -94.38443593589244},
#   'SNPC': {'investment_start_date': datetime.date(2019, 5, 31),
#    'investment_buy_usd_price': 0.00263117900773,
#    'investment_buy_btc_price': 3.0686086672050274e-07,
#    'investment_coins_amount': 38005.77600619925,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.011662485365647589,
#    'current_usd_value': 24.837171116639595,
#    'profit_and_loss_usd': -75.1628288833604,
#    'current_btc_value': 0.003109092219517173,
#    'profit_and_loss_btc': -0.008553393146130416,
#    'profit_and_loss_usd_perc': -75.1628288833604,
#    'profit_and_loss_btc_perc': -73.3410836366393},
#   'UPX': {'investment_start_date': datetime.date(2019, 5, 31),
#    'investment_buy_usd_price': 0.000337045421483,
#    'investment_buy_btc_price': 3.930787295604011e-08,
#    'investment_coins_amount': 296695.91582048486,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.011662485365647589,
#    'current_usd_value': 31.08911752604394,
#    'profit_and_loss_usd': -68.91088247395606,
#    'current_btc_value': 0.004109954777169758,
#    'profit_and_loss_btc': -0.007552530588477831,
#    'profit_and_loss_usd_perc': -68.91088247395606,
#    'profit_and_loss_btc_perc': -64.75918598555478},
#   'MHC': {'investment_start_date': datetime.date(2019, 6, 4),
#    'investment_buy_usd_price': 0.0209732792142,
#    'investment_buy_btc_price': 2.7210564296383582e-06,
#    'investment_coins_amount': 4767.971616584154,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.01297391982363951,
#    'current_usd_value': 16.24958999197683,
#    'profit_and_loss_usd': -83.75041000802317,
#    'current_btc_value': 0.0022514380446953144,
#    'profit_and_loss_btc': -0.010722481778944195,
#    'profit_and_loss_usd_perc': -83.75041000802317,
#    'profit_and_loss_btc_perc': -82.64643164671779},
#   'WLO': {'investment_start_date': datetime.date(2019, 6, 4),
#    'investment_buy_usd_price': 0.0487347507203,
#    'investment_buy_btc_price': 6.322807484702301e-06,
#    'investment_coins_amount': 2051.923904852271,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.01297391982363951,
#    'current_usd_value': 15.237347411006287,
#    'profit_and_loss_usd': -84.76265258899372,
#    'current_btc_value': 0.0021111882624926304,
#    'profit_and_loss_btc': -0.01086273156114688,
#    'profit_and_loss_usd_perc': -84.76265258899372,
#    'profit_and_loss_btc_perc': -83.7274448185977},
#   'GBT': {'investment_start_date': datetime.date(2019, 6, 4),
#    'investment_buy_usd_price': 0.00135337193559,
#    'investment_buy_btc_price': 1.7558538983908474e-07,
#    'investment_coins_amount': 73889.51800334561,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.01297391982363951,
#    'current_usd_value': 49.96351530905769,
#    'profit_and_loss_usd': -50.03648469094231,
#    'current_btc_value': 0.005397873198503362,
#    'profit_and_loss_btc': -0.007576046625136147,
#    'profit_and_loss_usd_perc': -50.03648469094231,
#    'profit_and_loss_btc_perc': -58.39443073582118},
#   'SCC': {'investment_start_date': datetime.date(2019, 6, 6),
#    'investment_buy_usd_price': 0.0726125417594,
#    'investment_buy_btc_price': 9.28308932493047e-06,
#    'investment_coins_amount': 1377.1725596846302,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.012784415887395562,
#    'current_usd_value': 2.91963311970904,
#    'profit_and_loss_usd': -97.08036688029097,
#    'current_btc_value': 0.0004045254732895401,
#    'profit_and_loss_btc': -0.012379890414106021,
#    'profit_and_loss_usd_perc': -97.08036688029097,
#    'profit_and_loss_btc_perc': -96.83579228920132},
#   'MNC': {'investment_start_date': datetime.date(2019, 6, 7),
#    'investment_buy_usd_price': 0.00529845001933,
#    'investment_buy_btc_price': 6.586874762754989e-07,
#    'investment_coins_amount': 18873.44405159553,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.012431701230972285,
#    'current_usd_value': 27.64018705918055,
#    'profit_and_loss_usd': -72.35981294081945,
#    'current_btc_value': 0.003678162801017422,
#    'profit_and_loss_btc': -0.008753538429954862,
#    'profit_and_loss_usd_perc': -72.35981294081945,
#    'profit_and_loss_btc_perc': -70.41303734155335},
#   'SHMN': {'investment_start_date': datetime.date(2019, 6, 9),
#    'investment_buy_usd_price': 0.512741794841,
#    'investment_buy_btc_price': 6.669311291428764e-05,
#    'investment_coins_amount': 195.02993710705746,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.013007153617147401,
#    'current_usd_value': 91.28445877074293,
#    'profit_and_loss_usd': -8.71554122925707,
#    'current_btc_value': 0.010970363625474546,
#    'profit_and_loss_btc': -0.0020367899916728556,
#    'profit_and_loss_usd_perc': -8.71554122925707,
#    'profit_and_loss_btc_perc': -15.658998514384763},
#   'HBX': {'investment_start_date': datetime.date(2019, 6, 10),
#    'investment_buy_usd_price': 0.0147789068484,
#    'investment_buy_btc_price': 1.8472871963266898e-06,
#    'investment_coins_amount': 6766.400318087548,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.01249948467282397,
#    'current_usd_value': 20.56944084060663,
#    'profit_and_loss_usd': -79.43055915939337,
#    'current_btc_value': 0.0028499686262556233,
#    'profit_and_loss_btc': -0.009649516046568347,
#    'profit_and_loss_usd_perc': -79.43055915939337,
#    'profit_and_loss_btc_perc': -77.19931100478131},
#   'BTT': {'investment_start_date': datetime.date(2019, 6, 13),
#    'investment_buy_usd_price': 0.001322569312,
#    'investment_buy_btc_price': 1.6068297304249693e-07,
#    'investment_coins_amount': 75610.4040012687,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.01214930450786816,
#    'current_usd_value': 21.98929151601243,
#    'profit_and_loss_usd': -78.01070848398757,
#    'current_btc_value': 0.003046693948554421,
#    'profit_and_loss_btc': -0.00910261055931374,
#    'profit_and_loss_usd_perc': -78.01070848398757,
#    'profit_and_loss_btc_perc': -74.92289417405487},
#   'NET': {'investment_start_date': datetime.date(2019, 6, 17),
#    'investment_buy_usd_price': 0.996094003311,
#    'investment_buy_btc_price': 0.00010687300048361599,
#    'investment_coins_amount': 100.39213133258674,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.010729208300458782,
#    'current_usd_value': 70.60207690663384,
#    'profit_and_loss_usd': -29.39792309336616,
#    'current_btc_value': 0.009782166938401763,
#    'profit_and_loss_btc': -0.0009470413620570189,
#    'profit_and_loss_usd_perc': -29.397923093366163,
#    'profit_and_loss_btc_perc': -8.82675902579432},
#   'SERV': {'investment_start_date': datetime.date(2019, 6, 17),
#    'investment_buy_usd_price': 0.0265013011827,
#    'investment_buy_btc_price': 2.8433798062238297e-06,
#    'investment_coins_amount': 3773.399627082455,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.010729208300458782,
#    'current_usd_value': 18.13137857565548,
#    'profit_and_loss_usd': -81.86862142434452,
#    'current_btc_value': 0.0018478918642036322,
#    'profit_and_loss_btc': -0.00888131643625515,
#    'profit_and_loss_usd_perc': -81.86862142434452,
#    'profit_and_loss_btc_perc': -82.77699703039025},
#   'ELD': {'investment_start_date': datetime.date(2019, 6, 18),
#    'investment_buy_usd_price': 0.0970259332294,
#    'investment_buy_btc_price': 1.0683601280502653e-05,
#    'investment_coins_amount': 1030.6522871938616,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.011011078095217328,
#    'current_usd_value': 439.5702162035648,
#    'profit_and_loss_usd': 339.5702162035648,
#    'current_btc_value': 0.041074837207464875,
#    'profit_and_loss_btc': 0.030063759112247547,
#    'profit_and_loss_usd_perc': 339.5702162035648,
#    'profit_and_loss_btc_perc': 273.03193068175375},
#   'OWC': {'investment_start_date': datetime.date(2019, 6, 18),
#    'investment_buy_usd_price': 0.103018499709,
#    'investment_buy_btc_price': 1.1343447455479225e-05,
#    'investment_coins_amount': 970.6994402216451,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.011011078095217328,
#    'current_usd_value': 125.3546068966078,
#    'profit_and_loss_usd': 25.354606896607805,
#    'current_btc_value': 0.0173683232121055,
#    'profit_and_loss_btc': 0.006357245116888174,
#    'profit_and_loss_usd_perc': 25.354606896607805,
#    'profit_and_loss_btc_perc': 57.73499254037122},
#   'SAFE': {'investment_start_date': datetime.date(2019, 6, 21),
#    'investment_buy_usd_price': 0.0755692550389,
#    'investment_buy_btc_price': 7.449241711444398e-06,
#    'investment_coins_amount': 1323.2894772950197,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.009857503170581516,
#    'current_usd_value': 663.4109074661822,
#    'profit_and_loss_usd': 563.4109074661822,
#    'current_btc_value': 0.09191792267205992,
#    'profit_and_loss_btc': 0.08206041950147841,
#    'profit_and_loss_usd_perc': 563.4109074661822,
#    'profit_and_loss_btc_perc': 832.4665798371483},
#   'COT': {'investment_start_date': datetime.date(2019, 6, 21),
#    'investment_buy_usd_price': 5.2994354418e-05,
#    'investment_buy_btc_price': 5.223920166983555e-09,
#    'investment_coins_amount': 1886993.4561564187,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.009857503170581514,
#    'current_usd_value': 44.37354910924768,
#    'profit_and_loss_usd': -55.62645089075232,
#    'current_btc_value': 0.0061481118411014345,
#    'profit_and_loss_btc': -0.0037093913294800798,
#    'profit_and_loss_usd_perc': -55.62645089075231,
#    'profit_and_loss_btc_perc': -37.63013072671682},
#   'TEMCO': {'investment_start_date': datetime.date(2019, 6, 24),
#    'investment_buy_usd_price': 0.00375239615687,
#    'investment_buy_btc_price': 3.407829665031565e-07,
#    'investment_coins_amount': 26649.63820968556,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.009081742765332513,
#    'current_usd_value': 13.111476576566725,
#    'profit_and_loss_usd': -86.88852342343327,
#    'current_btc_value': 0.0018166413553319819,
#    'profit_and_loss_btc': -0.007265101410000531,
#    'profit_and_loss_usd_perc': -86.88852342343327,
#    'profit_and_loss_btc_perc': -79.99677592425766},
#   'AID': {'investment_start_date': datetime.date(2019, 6, 24),
#    'investment_buy_usd_price': 0.0178188918566,
#    'investment_buy_btc_price': 1.618265922049195e-06,
#    'investment_coins_amount': 5612.021263991266,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.009081742765332515,
#    'current_usd_value': 9.694544132328636,
#    'profit_and_loss_usd': -90.30545586767137,
#    'current_btc_value': 0.0012989958826348526,
#    'profit_and_loss_btc': -0.007782746882697662,
#    'profit_and_loss_usd_perc': -90.30545586767137,
#    'profit_and_loss_btc_perc': -85.69662325612796},
#   'DCTO': {'investment_start_date': datetime.date(2019, 6, 24),
#    'investment_buy_usd_price': 0.00204766101157,
#    'investment_buy_btc_price': 1.8596330577679303e-07,
#    'investment_coins_amount': 48836.20845196792,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.009081742765332515,
#    'current_usd_value': 95.2239882462275,
#    'profit_and_loss_usd': -4.776011753772494,
#    'current_btc_value': 0.008740083248546136,
#    'profit_and_loss_btc': -0.0003416595167863787,
#    'profit_and_loss_usd_perc': -4.776011753772494,
#    'profit_and_loss_btc_perc': -3.7620479418398207},
#   'FET': {'investment_start_date': datetime.date(2019, 6, 25),
#    'investment_buy_usd_price': 0.16235720367,
#    'investment_buy_btc_price': 1.3769684758228965e-05,
#    'investment_coins_amount': 615.9258581667589,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.008481104901397914,
#    'current_usd_value': 33.2509160387044,
#    'profit_and_loss_usd': -66.7490839612956,
#    'current_btc_value': 0.004607031772953761,
#    'profit_and_loss_btc': -0.0038740731284441533,
#    'profit_and_loss_usd_perc': -66.7490839612956,
#    'profit_and_loss_btc_perc': -45.6788729002232},
#   'ONOT': {'investment_start_date': datetime.date(2019, 6, 25),
#    'investment_buy_usd_price': 8.97105125537e-05,
#    'investment_buy_btc_price': 7.608442677261041e-09,
#    'investment_coins_amount': 1114696.5629043842,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.008481104901397914,
#    'current_usd_value': 30.965152410729694,
#    'profit_and_loss_usd': -69.0348475892703,
#    'current_btc_value': 0.0036098437672382826,
#    'profit_and_loss_btc': -0.004871261134159631,
#    'profit_and_loss_usd_perc': -69.0348475892703,
#    'profit_and_loss_btc_perc': -57.436633443323124},
#   'LUNES': {'investment_start_date': datetime.date(2019, 6, 25),
#    'investment_buy_usd_price': 0.00779999164676,
#    'investment_buy_btc_price': 6.615254738619902e-07,
#    'investment_coins_amount': 12820.526550376308,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.008481104901397913,
#    'current_usd_value': 20.706025419538435,
#    'profit_and_loss_usd': -79.29397458046157,
#    'current_btc_value': 0.002868892901728271,
#    'profit_and_loss_btc': -0.005612211999669641,
#    'profit_and_loss_usd_perc': -79.29397458046157,
#    'profit_and_loss_btc_perc': -66.17312325360577},
#   'OBSR': {'investment_start_date': datetime.date(2019, 6, 26),
#    'investment_buy_usd_price': 0.00238883505177,
#    'investment_buy_btc_price': 1.8352739093128537e-07,
#    'investment_coins_amount': 41861.408524588296,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.007682715087226358,
#    'current_usd_value': 34.87157024997491,
#    'profit_and_loss_usd': -65.12842975002509,
#    'current_btc_value': 0.004711801711346734,
#    'profit_and_loss_btc': -0.002970913375879624,
#    'profit_and_loss_usd_perc': -65.12842975002509,
#    'profit_and_loss_btc_perc': -38.67009699239275},
#   'PIB': {'investment_start_date': datetime.date(2019, 6, 28),
#    'investment_buy_usd_price': 0.000717732956599,
#    'investment_buy_btc_price': 5.784748539933444e-08,
#    'investment_coins_amount': 139327.58567177007,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.008059750477872238,
#    'current_usd_value': 17.578071172435802,
#    'profit_and_loss_usd': -82.4219288275642,
#    'current_btc_value': 0.00243550380098971,
#    'profit_and_loss_btc': -0.005624246676882527,
#    'profit_and_loss_usd_perc': -82.4219288275642,
#    'profit_and_loss_btc_perc': -69.78189575872975},
#   'NAVY': {'investment_start_date': datetime.date(2019, 6, 28),
#    'investment_buy_usd_price': 0.00700805461877,
#    'investment_buy_btc_price': 5.648317156258625e-07,
#    'investment_coins_amount': 14269.295181028601,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.008059750477872238,
#    'current_usd_value': 100.0,
#    'profit_and_loss_usd': 0.0,
#    'current_btc_value': 0.008059750477872238,
#    'profit_and_loss_btc': 0.0,
#    'profit_and_loss_usd_perc': 0.0,
#    'profit_and_loss_btc_perc': 0.0},
#   'CELR': {'investment_start_date': datetime.date(2019, 7, 4),
#    'investment_buy_usd_price': 0.0162422958293,
#    'investment_buy_btc_price': 1.4482088424416358e-06,
#    'investment_coins_amount': 6156.765093491696,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.008916281649230678,
#    'current_usd_value': 27.860844327418125,
#    'profit_and_loss_usd': -72.13915567258188,
#    'current_btc_value': 0.00386021831363462,
#    'profit_and_loss_btc': -0.005056063335596057,
#    'profit_and_loss_usd_perc': -72.13915567258188,
#    'profit_and_loss_btc_perc': -56.70596258062697},
#   'ANKR': {'investment_start_date': datetime.date(2019, 7, 4),
#    'investment_buy_usd_price': 0.00825755809726,
#    'investment_buy_btc_price': 7.362671373005554e-07,
#    'investment_coins_amount': 12110.117642791,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.00891628164923068,
#    'current_usd_value': 21.266868979616532,
#    'profit_and_loss_usd': -78.73313102038347,
#    'current_btc_value': 0.002946599756418491,
#    'profit_and_loss_btc': -0.005969681892812188,
#    'profit_and_loss_usd_perc': -78.73313102038347,
#    'profit_and_loss_btc_perc': -66.95259445205241},
#   'RIF': {'investment_start_date': datetime.date(2019, 7, 5),
#    'investment_buy_usd_price': 0.103255502939,
#    'investment_buy_btc_price': 9.405281195389385e-06,
#    'investment_coins_amount': 968.4713855790984,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.009108745711059798,
#    'current_usd_value': 55.309255596225846,
#    'profit_and_loss_usd': -44.690744403774154,
#    'current_btc_value': 0.007663292571357429,
#    'profit_and_loss_btc': -0.0014454531397023688,
#    'profit_and_loss_usd_perc': -44.690744403774154,
#    'profit_and_loss_btc_perc': -15.868849406426026},
#   'PTON': {'investment_start_date': datetime.date(2019, 7, 5),
#    'investment_buy_usd_price': 0.00100386928792,
#    'investment_buy_btc_price': 9.143990070805954e-08,
#    'investment_coins_amount': 99614.56257636717,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.0091087457110598,
#    'current_usd_value': 3.4190310600612004,
#    'profit_and_loss_usd': -96.5809689399388,
#    'current_btc_value': 0.00045303200690337037,
#    'profit_and_loss_btc': -0.008655713704156428,
#    'profit_and_loss_usd_perc': -96.5809689399388,
#    'profit_and_loss_btc_perc': -95.02640625532776},
#   'XQR': {'investment_start_date': datetime.date(2019, 7, 5),
#    'investment_buy_usd_price': 0.00107514522435,
#    'investment_buy_btc_price': 9.793224451064487e-08,
#    'investment_coins_amount': 93010.69077478064,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.0091087457110598,
#    'current_usd_value': 43.38869961451269,
#    'profit_and_loss_usd': -56.61130038548731,
#    'current_btc_value': 0.0060116574676778506,
#    'profit_and_loss_btc': -0.0030970882433819487,
#    'profit_and_loss_usd_perc': -56.61130038548731,
#    'profit_and_loss_btc_perc': -34.001259247159325},
#   'TOP': {'investment_start_date': datetime.date(2019, 7, 18),
#    'investment_buy_usd_price': 0.00477365009935,
#    'investment_buy_btc_price': 4.475374091800826e-07,
#    'investment_coins_amount': 20948.330505752067,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.009375161561192369,
#    'current_usd_value': 32.05354023723582,
#    'profit_and_loss_usd': -67.94645976276418,
#    'current_btc_value': 0.004441131129641839,
#    'profit_and_loss_btc': -0.0049340304315505295,
#    'profit_and_loss_usd_perc': -67.94645976276418,
#    'profit_and_loss_btc_perc': -52.628750975071206},
#   'OTO': {'investment_start_date': datetime.date(2019, 7, 18),
#    'investment_buy_usd_price': 0.608187777237,
#    'investment_buy_btc_price': 5.70185867113935e-05,
#    'investment_coins_amount': 164.42290316043588,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.00937516156119237,
#    'current_usd_value': 45.63273920265754,
#    'profit_and_loss_usd': -54.36726079734246,
#    'current_btc_value': 0.006322577072729195,
#    'profit_and_loss_btc': -0.003052584488463175,
#    'profit_and_loss_usd_perc': -54.36726079734246,
#    'profit_and_loss_btc_perc': -32.56034009162115},
#   'VIDT': {'investment_start_date': datetime.date(2019, 7, 18),
#    'investment_buy_usd_price': 0.239719085332,
#    'investment_buy_btc_price': 2.2474051542887602e-05,
#    'investment_coins_amount': 417.154937252929,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.00937516156119237,
#    'current_usd_value': 29.846868804921556,
#    'profit_and_loss_usd': -70.15313119507844,
#    'current_btc_value': 0.004135389014468001,
#    'profit_and_loss_btc': -0.005239772546724369,
#    'profit_and_loss_usd_perc': -70.15313119507844,
#    'profit_and_loss_btc_perc': -55.88994400282051},
#   'OVC': {'investment_start_date': datetime.date(2019, 7, 18),
#    'investment_buy_usd_price': 0.114868880069,
#    'investment_buy_btc_price': 1.0769143090001051e-05,
#    'investment_coins_amount': 870.5578041670773,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.00937516156119237,
#    'current_usd_value': 61.6063587734046,
#    'profit_and_loss_usd': -38.3936412265954,
#    'current_btc_value': 0.00832417194343514,
#    'profit_and_loss_btc': -0.0010509896177572295,
#    'profit_and_loss_usd_perc': -38.3936412265954,
#    'profit_and_loss_btc_perc': -11.210362732389653},
#   'TFUEL': {'investment_start_date': datetime.date(2019, 7, 19),
#    'investment_buy_usd_price': 0.00722470626246,
#    'investment_buy_btc_price': 6.860592248205064e-07,
#    'investment_coins_amount': 13841.393181561705,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.009496015476578067,
#    'current_usd_value': 34.964154009493,
#    'profit_and_loss_usd': -65.035845990507,
#    'current_btc_value': 0.004844406940509038,
#    'profit_and_loss_btc': -0.004651608536069029,
#    'profit_and_loss_usd_perc': -65.035845990507,
#    'profit_and_loss_btc_perc': -48.984845776022865},
#   'FST': {'investment_start_date': datetime.date(2019, 7, 19),
#    'investment_buy_usd_price': 3.08013202756,
#    'investment_buy_btc_price': 0.0002924898140361354,
#    'investment_coins_amount': 32.46614077099071,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.009496015476578067,
#    'current_usd_value': 55.8485483517635,
#    'profit_and_loss_usd': -44.1514516482365,
#    'current_btc_value': 0.007738013486017156,
#    'profit_and_loss_btc': -0.0017580019905609106,
#    'profit_and_loss_usd_perc': -44.15145164823651,
#    'profit_and_loss_btc_perc': -18.513048919275928},
#   'VNT': {'investment_start_date': datetime.date(2019, 7, 19),
#    'investment_buy_usd_price': 0.0025458091359,
#    'investment_buy_btc_price': 2.4175042954920237e-07,
#    'investment_coins_amount': 39280.24241481394,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.009496015476578069,
#    'current_usd_value': 67.0511023736483,
#    'profit_and_loss_usd': -32.948897626351695,
#    'current_btc_value': 0.009290166884046222,
#    'profit_and_loss_btc': -0.0002058485925318463,
#    'profit_and_loss_usd_perc': -32.948897626351695,
#    'profit_and_loss_btc_perc': -2.167736489473633},
#   'HLT': {'investment_start_date': datetime.date(2019, 7, 19),
#    'investment_buy_usd_price': 0.267868376934,
#    'investment_buy_btc_price': 2.5436822530511114e-05,
#    'investment_coins_amount': 373.31767618332555,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.009496015476578067,
#    'current_usd_value': 59.687820717409274,
#    'profit_and_loss_usd': -40.312179282590726,
#    'current_btc_value': 0.00826995822260621,
#    'profit_and_loss_btc': -0.0012260572539718566,
#    'profit_and_loss_usd_perc': -40.312179282590726,
#    'profit_and_loss_btc_perc': -12.911281126235822},
#   'VEIL': {'investment_start_date': datetime.date(2019, 7, 19),
#    'investment_buy_usd_price': 0.21958695902,
#    'investment_buy_btc_price': 2.0852011613086336e-05,
#    'investment_coins_amount': 455.40045021932286,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.009496015476578067,
#    'current_usd_value': 19.10692111268712,
#    'profit_and_loss_usd': -80.89307888731288,
#    'current_btc_value': 0.0026473313561348874,
#    'profit_and_loss_btc': -0.00684868412044318,
#    'profit_and_loss_usd_perc': -80.89307888731288,
#    'profit_and_loss_btc_perc': -72.12166131505857},
#   'CSP': {'investment_start_date': datetime.date(2019, 7, 19),
#    'investment_buy_usd_price': 0.00850752146323,
#    'investment_buy_btc_price': 8.078755548215217e-07,
#    'investment_coins_amount': 11754.304756350693,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.009496015476578067,
#    'current_usd_value': 74.61785086357976,
#    'profit_and_loss_usd': -25.38214913642024,
#    'current_btc_value': 0.010338566593410212,
#    'profit_and_loss_btc': 0.0008425511168321451,
#    'profit_and_loss_usd_perc': -25.38214913642024,
#    'profit_and_loss_btc_perc': 8.872680535434029},
#   'XBASE': {'investment_start_date': datetime.date(2019, 7, 19),
#    'investment_buy_usd_price': 0.00408353546688,
#    'investment_buy_btc_price': 3.8777315992647925e-07,
#    'investment_coins_amount': 24488.58368221897,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.009496015476578067,
#    'current_usd_value': 51.15010487140162,
#    'profit_and_loss_usd': -48.84989512859838,
#    'current_btc_value': 0.0070870275591254405,
#    'profit_and_loss_btc': -0.0024089879174526265,
#    'profit_and_loss_usd_perc': -48.84989512859838,
#    'profit_and_loss_btc_perc': -25.368407658921765},
#   'DOS': {'investment_start_date': datetime.date(2019, 7, 19),
#    'investment_buy_usd_price': 0.0144622580904,
#    'investment_buy_btc_price': 1.3733382665270478e-06,
#    'investment_coins_amount': 6914.549538178942,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.009496015476578067,
#    'current_usd_value': 87.35727972858054,
#    'profit_and_loss_usd': -12.642720271419464,
#    'current_btc_value': 0.012103659425199448,
#    'profit_and_loss_btc': 0.002607643948621381,
#    'profit_and_loss_usd_perc': -12.642720271419464,
#    'profit_and_loss_btc_perc': 27.460401207781704},
# ...
#    'current_btc_value': 0.016006911843999213,
#    'profit_and_loss_btc': 0.0035493737415020227,
#    'profit_and_loss_usd_perc': 15.528719573495962,
#    'profit_and_loss_btc_perc': 28.49177511879758},
#   'SWACE': {'investment_start_date': datetime.date(2019, 11, 20),
#    'investment_buy_usd_price': 0.00170145459932,
#    'investment_buy_btc_price': 2.1195935500697986e-07,
#    'investment_coins_amount': 58773.24028508654,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.01245753810249719,
#    'current_usd_value': 294.8623275646064,
#    'profit_and_loss_usd': 194.8623275646064,
#    'current_btc_value': 0.039070154576016494,
#    'profit_and_loss_btc': 0.026612616473519306,
#    'profit_and_loss_usd_perc': 194.86232756460637,
#    'profit_and_loss_btc_perc': 213.62661108927006},
#   'AYA': {'investment_start_date': datetime.date(2019, 11, 27),
#    'investment_buy_usd_price': 0.00703437064288,
#    'investment_buy_btc_price': 9.339730204127549e-07,
#    'investment_coins_amount': 14215.912848040969,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.01327727906060931,
#    'current_usd_value': 118.72312146891332,
#    'profit_and_loss_usd': 18.72312146891332,
#    'current_btc_value': 0.016449507500932128,
#    'profit_and_loss_btc': 0.0031722284403228173,
#    'profit_and_loss_usd_perc': 18.72312146891332,
#    'profit_and_loss_btc_perc': 23.89215761634553},
#   'QBX': {'investment_start_date': datetime.date(2019, 11, 27),
#    'investment_buy_usd_price': 0.00105707285999,
#    'investment_buy_btc_price': 1.4035051349483627e-07,
#    'investment_coins_amount': 94600.85845070888,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.013277279060609312,
#    'current_usd_value': 100.0,
#    'profit_and_loss_usd': 0.0,
#    'current_btc_value': 0.013277279060609312,
#    'profit_and_loss_btc': 0.0,
#    'profit_and_loss_usd_perc': 0.0,
#    'profit_and_loss_btc_perc': 0.0},
#   'THX': {'investment_start_date': datetime.date(2019, 11, 29),
#    'investment_buy_usd_price': 5.71012263877,
#    'investment_buy_btc_price': 0.000735722640828405,
#    'investment_coins_amount': 17.512758713977586,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.01288453308923825,
#    'current_usd_value': 59.41040349005093,
#    'profit_and_loss_usd': -40.58959650994907,
#    'current_btc_value': 0.008231521086639283,
#    'profit_and_loss_btc': -0.004653012002598968,
#    'profit_and_loss_usd_perc': -40.58959650994907,
#    'profit_and_loss_btc_perc': -36.1131596338976},
#   'WIN': {'investment_start_date': datetime.date(2019, 11, 29),
#    'investment_buy_usd_price': 0.000113365866787,
#    'investment_buy_btc_price': 1.4606662618072771e-08,
#    'investment_coins_amount': 882099.7257303845,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.01288453308923825,
#    'current_usd_value': 84.21074473630487,
#    'profit_and_loss_usd': -15.789255263695125,
#    'current_btc_value': 0.011667695896638276,
#    'profit_and_loss_btc': -0.0012168371925999743,
#    'profit_and_loss_usd_perc': -15.789255263695125,
#    'profit_and_loss_btc_perc': -9.444169875401478},
#   'BHT': {'investment_start_date': datetime.date(2019, 11, 29),
#    'investment_buy_usd_price': 0.0286965613025,
#    'investment_buy_btc_price': 3.6974179364941516e-06,
#    'investment_coins_amount': 3484.738082234548,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.01288453308923825,
#    'current_usd_value': 91.6383783317935,
#    'profit_and_loss_usd': -8.361621668206496,
#    'current_btc_value': 0.012696820746385068,
#    'profit_and_loss_btc': -0.00018771234285318295,
#    'profit_and_loss_usd_perc': -8.361621668206496,
#    'profit_and_loss_btc_perc': -1.4568812199331371},
#   'NYE': {'investment_start_date': datetime.date(2019, 11, 29),
#    'investment_buy_usd_price': 3.26693289681,
#    'investment_buy_btc_price': 0.0004209290500926942,
#    'investment_coins_amount': 30.609750233206533,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.01288453308923825,
#    'current_usd_value': 93.63431639220182,
#    'profit_and_loss_usd': -6.365683607798175,
#    'current_btc_value': 0.012973365009118925,
#    'profit_and_loss_btc': 8.883191988067439e-05,
#    'profit_and_loss_usd_perc': -6.365683607798176,
#    'profit_and_loss_btc_perc': 0.6894461698023878},
#   'TRV': {'investment_start_date': datetime.date(2019, 11, 29),
#    'investment_buy_usd_price': 0.019165090052,
#    'investment_buy_btc_price': 2.4693323693322485e-06,
#    'investment_coins_amount': 5217.820512644257,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.01288453308923825,
#    'current_usd_value': 77.19403336774887,
#    'profit_and_loss_usd': -22.805966632251128,
#    'current_btc_value': 0.010695505771742008,
#    'profit_and_loss_btc': -0.0021890273174962425,
#    'profit_and_loss_usd_perc': -22.805966632251128,
#    'profit_and_loss_btc_perc': -16.989574261908007},
#   'FAT': {'investment_start_date': datetime.date(2019, 11, 29),
#    'investment_buy_usd_price': 0.0168895232344,
#    'investment_buy_btc_price': 2.1761362097508504e-06,
#    'investment_coins_amount': 5920.830245600032,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.01288453308923825,
#    'current_usd_value': 93.15862194886256,
#    'profit_and_loss_usd': -6.84137805113744,
#    'current_btc_value': 0.012907455865078184,
#    'profit_and_loss_btc': 2.2922775839933837e-05,
#    'profit_and_loss_usd_perc': -6.84137805113744,
#    'profit_and_loss_btc_perc': 0.1779092473213483},
#   'EOSDT': {'investment_start_date': datetime.date(2019, 11, 29),
#    'investment_buy_usd_price': 1.00229556407,
#    'investment_buy_btc_price': 0.00012914110360456632,
#    'investment_coins_amount': 99.77096934753672,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.012884533089238252,
#    'current_usd_value': 99.61825794364857,
#    'profit_and_loss_usd': -0.38174205635142755,
#    'current_btc_value': 0.013802461230796658,
#    'profit_and_loss_btc': 0.0009179281415584058,
#    'profit_and_loss_usd_perc': -0.38174205635142755,
#    'profit_and_loss_btc_perc': 7.124263915508906},
#   'KICKS': {'investment_start_date': datetime.date(2019, 11, 29),
#    'investment_buy_usd_price': 0.203311107804,
#    'investment_buy_btc_price': 2.6195686959103232e-05,
#    'investment_coins_amount': 491.8570415562537,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.012884533089238252,
#    'current_usd_value': 81.97929899416978,
#    'profit_and_loss_usd': -18.02070100583022,
#    'current_btc_value': 0.011358521213400306,
#    'profit_and_loss_btc': -0.0015260118758379463,
#    'profit_and_loss_usd_perc': -18.02070100583022,
#    'profit_and_loss_btc_perc': -11.843749907495994},
#   'DAB': {'investment_start_date': datetime.date(2019, 11, 29),
#    'investment_buy_usd_price': 0.20428287671,
#    'investment_buy_btc_price': 2.6320894845347732e-05,
#    'investment_coins_amount': 489.5172890185995,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.01288453308923825,
#    'current_usd_value': 182.2222938653075,
#    'profit_and_loss_usd': 82.2222938653075,
#    'current_btc_value': 0.025247541950447254,
#    'profit_and_loss_btc': 0.012363008861209003,
#    'profit_and_loss_usd_perc': 82.2222938653075,
#    'profit_and_loss_btc_perc': 95.95232342206604},
#   'ZNZ': {'investment_start_date': datetime.date(2019, 12, 1),
#    'investment_buy_usd_price': 0.0264080653193,
#    'investment_buy_btc_price': 3.5569808375170266e-06,
#    'investment_coins_amount': 3786.7219272180555,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.01346929733212017,
#    'current_usd_value': 94.55685179425288,
#    'profit_and_loss_usd': -5.443148205747121,
#    'current_btc_value': 0.012914095235126075,
#    'profit_and_loss_btc': -0.0005552020969940945,
#    'profit_and_loss_usd_perc': -5.443148205747121,
#    'profit_and_loss_btc_perc': -4.121982634313868},
#   'COCOS': {'investment_start_date': datetime.date(2019, 12, 5),
#    'investment_buy_usd_price': 0.000770287498666,
#    'investment_buy_btc_price': 1.0341778941199371e-07,
#    'investment_coins_amount': 129821.65772283997,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.01342586885949659,
#    'current_usd_value': 96.33900245936255,
#    'profit_and_loss_usd': -3.660997540637453,
#    'current_btc_value': 0.013348108809643714,
#    'profit_and_loss_btc': -7.776004985287667e-05,
#    'profit_and_loss_usd_perc': -3.660997540637453,
#    'profit_and_loss_btc_perc': -0.5791807641400746},
#   'PERL': {'investment_start_date': datetime.date(2019, 12, 5),
#    'investment_buy_usd_price': 0.0272072557833,
#    'investment_buy_btc_price': 3.65281048173366e-06,
#    'investment_coins_amount': 3675.490126475037,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.013425868859496589,
#    'current_usd_value': 84.7309749884811,
#    'profit_and_loss_usd': -15.269025011518906,
#    'current_btc_value': 0.011739775634178072,
#    'profit_and_loss_btc': -0.001686093225318517,
#    'profit_and_loss_usd_perc': -15.269025011518906,
#    'profit_and_loss_btc_perc': -12.558540850977282},
#   'FOR': {'investment_start_date': datetime.date(2019, 12, 5),
#    'investment_buy_usd_price': 0.0212237066745,
#    'investment_buy_btc_price': 2.8494670252425946e-06,
#    'investment_coins_amount': 4711.712309902429,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.01342586885949659,
#    'current_usd_value': 90.43416508700957,
#    'profit_and_loss_usd': -9.565834912990425,
#    'current_btc_value': 0.012529972751169733,
#    'profit_and_loss_btc': -0.0008958961083268581,
#    'profit_and_loss_usd_perc': -9.565834912990425,
#    'profit_and_loss_btc_perc': -6.672909721542224},
#   'MBN': {'investment_start_date': datetime.date(2019, 12, 5),
#    'investment_buy_usd_price': 0.00442583591979,
#    'investment_buy_btc_price': 5.942069265275e-07,
#    'investment_coins_amount': 22594.60174582,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.013425868859496589,
#    'current_usd_value': 102.45892888173684,
#    'profit_and_loss_usd': 2.4589288817368384,
#    'current_btc_value': 0.014196046215133496,
#    'profit_and_loss_btc': 0.0007701773556369074,
#    'profit_and_loss_usd_perc': 2.4589288817368384,
#    'profit_and_loss_btc_perc': 5.736517790371041},
#   'RUNE': {'investment_start_date': datetime.date(2019, 12, 6),
#    'investment_buy_usd_price': 0.106145904906,
#    'investment_buy_btc_price': 1.4064655008802032e-05,
#    'investment_coins_amount': 942.099462890795,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.013250303929536723,
#    'current_usd_value': 107.61325808297218,
#    'profit_and_loss_usd': 7.61325808297218,
#    'current_btc_value': 0.014910196717655408,
#    'profit_and_loss_btc': 0.0016598927881186845,
#    'profit_and_loss_usd_perc': 7.61325808297218,
#    'profit_and_loss_btc_perc': 12.527205390500956},
#   'MB8': {'investment_start_date': datetime.date(2019, 12, 6),
#    'investment_buy_usd_price': 0.0184744212,
#    'investment_buy_btc_price': 2.4479169582227656e-06,
#    'investment_coins_amount': 5412.889471200321,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.013250303929536723,
#    'current_usd_value': 83.94807980073553,
#    'profit_and_loss_usd': -16.051920199264472,
#    'current_btc_value': 0.011631302742765453,
#    'profit_and_loss_btc': -0.0016190011867712704,
#    'profit_and_loss_usd_perc': -16.051920199264472,
#    'profit_and_loss_btc_perc': -12.218596610167541},
#   'AXE': {'investment_start_date': datetime.date(2019, 12, 6),
#    'investment_buy_usd_price': 0.476255040898,
#    'investment_buy_btc_price': 6.310524039872443e-05,
#    'investment_coins_amount': 209.97153082400044,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.013250303929536725,
#    'current_usd_value': 96.14961297870495,
#    'profit_and_loss_usd': -3.850387021295049,
#    'current_btc_value': 0.013321868228667324,
#    'profit_and_loss_btc': 7.156429913059842e-05,
#    'profit_and_loss_usd_perc': -3.850387021295049,
#    'profit_and_loss_btc_perc': 0.5400955292132725},
#   'SEAL': {'investment_start_date': datetime.date(2019, 12, 6),
#    'investment_buy_usd_price': 0.0112380665647,
#    'investment_buy_btc_price': 1.4890779756263969e-06,
#    'investment_coins_amount': 8898.327788350263,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.013250303929536723,
#    'current_usd_value': 98.91365325256676,
#    'profit_and_loss_usd': -1.0863467474332396,
#    'current_btc_value': 0.013704835764015303,
#    'profit_and_loss_btc': 0.0004545318344785793,
#    'profit_and_loss_usd_perc': -1.0863467474332396,
#    'profit_and_loss_btc_perc': 3.4303502538184523},
#   'CRON': {'investment_start_date': datetime.date(2019, 12, 6),
#    'investment_buy_usd_price': 0.214370201053,
#    'investment_buy_btc_price': 2.8404703173881435e-05,
#    'investment_coins_amount': 466.4827457771354,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.013250303929536723,
#    'current_usd_value': 99.18682567892493,
#    'profit_and_loss_usd': -0.813174321075067,
#    'current_btc_value': 0.013742684767822057,
#    'profit_and_loss_btc': 0.0004923808382853341,
#    'profit_and_loss_usd_perc': -0.813174321075067,
#    'profit_and_loss_btc_perc': 3.715996560560022},
#   'ENQ': {'investment_start_date': datetime.date(2019, 12, 6),
#    'investment_buy_usd_price': 0.0219859318089,
#    'investment_buy_btc_price': 2.913202786419941e-06,
#    'investment_coins_amount': 4548.36305639407,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.013250303929536723,
#    'current_usd_value': 95.53740866783353,
#    'profit_and_loss_usd': -4.462591332166468,
#    'current_btc_value': 0.013237045160682045,
#    'profit_and_loss_btc': -1.3258768854678207e-05,
#    'profit_and_loss_usd_perc': -4.462591332166468,
#    'profit_and_loss_btc_perc': -0.10006388476208923},
#   'XCM': {'investment_start_date': datetime.date(2019, 12, 7),
#    'investment_buy_usd_price': 0.0276958477696,
#    'investment_buy_btc_price': 3.6652958317957202e-06,
#    'investment_coins_amount': 3610.6495396672326,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.013234098707817443,
#    'current_usd_value': 120.82774195752056,
#    'profit_and_loss_usd': 20.82774195752056,
#    'current_btc_value': 0.01674111009767673,
#    'profit_and_loss_btc': 0.003507011389859288,
#    'profit_and_loss_usd_perc': 20.82774195752056,
#    'profit_and_loss_btc_perc': 26.499812849270047},
#   'CREDIT': {'investment_start_date': datetime.date(2019, 12, 7),
#    'investment_buy_usd_price': 1.0370949101e-05,
#    'investment_buy_btc_price': 1.372501640963846e-09,
#    'investment_coins_amount': 9642319.041982153,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.013234098707817445,
#    'current_usd_value': 98.98902375588854,
#    'profit_and_loss_usd': -1.0109762441114611,
#    'current_btc_value': 0.013086264373122426,
#    'profit_and_loss_btc': -0.00014783433469501943,
#    'profit_and_loss_usd_perc': -1.0109762441114611,
#    'profit_and_loss_btc_perc': -1.1170714225343732},
#   'JWL': {'investment_start_date': datetime.date(2019, 12, 11),
#    'investment_buy_usd_price': 0.900599294957,
#    'investment_buy_btc_price': 0.00012478121089166602,
#    'investment_coins_amount': 111.03717331332643,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.013855352940024657,
#    'current_usd_value': 100.0,
#    'profit_and_loss_usd': 0.0,
#    'current_btc_value': 0.013855352940024657,
#    'profit_and_loss_btc': 0.0,
#    'profit_and_loss_usd_perc': 0.0,
#    'profit_and_loss_btc_perc': 0.0},
#   'STREAM': {'investment_start_date': datetime.date(2019, 12, 11),
#    'investment_buy_usd_price': 1.40373583222,
#    'investment_buy_btc_price': 0.00019449255389967335,
#    'investment_coins_amount': 71.2384750069752,
#    'investment_amount_usd': 100,
#    'investment_amount_btc': 0.013855352940024657,
#    'current_usd_value': 99.99999999999999,
#    'profit_and_loss_usd': -1.4210854715202004e-14,
#    'current_btc_value': 0.013855352940024657,
#    'profit_and_loss_btc': 0.0,
#    'profit_and_loss_usd_perc': -1.4210854715202004e-14,
#    'profit_and_loss_btc_perc': 0.0}},
#  'number_of_coins': 251,
#  'total_invested_amount_usd': 25100,
#  'profit_and_loss_usd': -2655.754601277986,
#  'profit_and_loss_btc': 0.10628838348383411}
